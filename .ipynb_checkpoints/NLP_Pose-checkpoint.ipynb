# %% [markdown]
# # Natural Language Processing for Campaign Speeches

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import timeit

# %matplotlib inline

import wikipedia
import spacy
from textblob import TextBlob, Word

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD, LatentDirichletAllocation
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
pd.set_option("display.max_rows", 999)
pd.set_option("display.max_columns", 999)

# %%
df_kerry = pd.read_csv('./csv_files/speech_kerry')
df_bush = pd.read_csv('./csv_files/speech_bush')
df_obama = pd.read_csv('./csv_files/speech_obama')
df_mccain = pd.read_csv('./csv_files/speech_mccain')
df_obama_2 = pd.read_csv('./csv_files/speech_obama_2')
df_romney = pd.read_csv('./csv_files/speech_romney')
df_clinton = pd.read_csv('./csv_files/speech_clinton')
df_trump = pd.read_csv('./csv_files/speech_trump')

# %%
df_kerry['party'] = 'dem'
df_bush['party'] = 'rep'
df_obama['party'] = 'dem'
df_mccain['party'] = 'rep'
df_obama_2['party'] = 'dem'
df_romney['party'] = 'rep'
df_clinton['party'] = 'dem'
df_trump['party'] = 'rep'

# %%
df = pd.concat([df_kerry, df_bush, df_obama, df_mccain, df_obama_2, df_romney, 
                df_clinton, df_trump], axis=0, ignore_index=True)

# %%
df.reindex()
df.shape
# Out:
# (1004, 4)

# %% [markdown]
# # Preprocessing

# %%
df['speech'] = df['speech'].apply(lambda x: x.replace("\\", "'"))
df['speech'] = df['speech'].apply(lambda x: x.lower().replace("kerry", ""))
df['speech'] = df['speech'].apply(lambda x: x.lower().replace("bush", ""))
df['speech'] = df['speech'].apply(lambda x: x.lower().replace("obama", ""))
df['speech'] = df['speech'].apply(lambda x: x.lower().replace("mccain", ""))
df['speech'] = df['speech'].apply(lambda x: x.lower().replace("romeny", ""))
df['speech'] = df['speech'].apply(lambda x: x.lower().replace("clinton", ""))
df['speech'] = df['speech'].apply(lambda x: x.lower().replace("trump", ""))

# %%
subjectivity = []
polarity = []
for i in range(0, len(df.speech)):
    sub = TextBlob(df.speech[i]).sentiment.subjectivity
    subjectivity.append(sub)
    
    pol = TextBlob(df.speech[i]).sentiment.polarity
    polarity.append(pol)

    
df['subjectivity'] = subjectivity
df['polarity'] = polarity

# %%
docs = df.speech

sp = []
for speech in docs:
    stem_list = []
    speech_new = []
    speech = speech.split()
    for word in speech:
        w = Word(word)
        stem = w.stem()
        stem_list.append(stem)
    speech_new = ' '.join(stem_list)
    sp.append(speech_new)

df.speech = sp

# %%
df.head()
# Out:
#   candidate  party                                             speech  year  \
# 0     kerry      1  thank you, max cleland for your friendship, yo...  2004
# 1     kerry      1  good morn and thank you for invit me into thi ...  2004
# 2     kerry      1  we are here tonight to honor our next gener of...  2004
# 3     kerry      1  today, from florida to mississippi, to louisia...  2004
# 4     kerry      1  thank you john, rich, linda, and member of the...  2004
#
#    subjectivity  polarity
# 0      0.470254  0.149970
# 1      0.506184  0.062693
# 2      0.456656  0.158972
# 3      0.454353  0.145098
# 4      0.422159  0.132524

# %%
df.party = df.party.apply(lambda x: 1 if x == 'dem' else 0)
X = df[['speech', 'subjectivity', 'polarity']]
y = df.party

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=42)

# %% [markdown]
# # Modeling Straight Predictions

# %% [markdown]
# Without Truncating

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf.fit(X_train.speech)
X_train_tf_tsvd = tfidf.transform(X_train.speech)


X_train_tf_tsvd = pd.DataFrame(X_train_tf_tsvd.todense())


train_sub_pol = X_train[['subjectivity', 'polarity']].reset_index().drop(['index'], axis=1)
X_train_tf_tsvd = pd.concat([X_train_tf_tsvd, train_sub_pol], axis=1)



rfc = RandomForestClassifier(n_estimators=100, max_depth=5)
rfc.fit(X_train_tf_tsvd, y_train)
train_predictions = rfc.predict(X_train_tf_tsvd)
print(rfc.score(X_train_tf_tsvd, y_train))
print(confusion_matrix(y_train, train_predictions))
print(classification_report(y_train, train_predictions))

X_test_tf_tsvd = tfidf.transform(X_test.speech)
X_test_tf_tsvd = pd.DataFrame(X_test_tf_tsvd.todense())

test_sub_pol = X_test[['subjectivity', 'polarity']].reset_index().drop(['index'], axis=1)
X_test_tf_tsvd = pd.concat([X_test_tf_tsvd, test_sub_pol], axis=1)

test_predictions = rfc.predict(X_test_tf_tsvd)
print(rfc.score(X_test_tf_tsvd, y_test))
print(confusion_matrix(y_test, test_predictions))
print(classification_report(y_test, test_predictions))
# Out:
# 1.0
# [[602]]
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       602
#
# avg / total       1.00      1.00      1.00       602
#
# 1.0
# [[402]]
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       402
#
# avg / total       1.00      1.00      1.00       402

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf.fit(X_train.speech)
X_train_tf_tsvd = tfidf.transform(X_train.speech)

tsvd = TruncatedSVD(n_components=100)
tsvd.fit(X_train_tf)
X_train_tf_tsvd = tsvd.transform(X_train_tf)

X_train_tf_tsvd = pd.DataFrame(X_train_tf_tsvd.todense())


train_sub_pol = X_train[['subjectivity', 'polarity']].reset_index().drop(['index'], axis=1)
X_train_tf_tsvd = pd.concat([X_train_tf_tsvd, train_sub_pol], axis=1)




rfc = RandomForestClassifier(n_estimators=100, max_depth=5)
rfc.fit(X_train_tf_tsvd, y_train)
train_predictions = rfc.predict(X_train_tf_tsvd)
print(rfc.score(X_train_tf_tsvd, y_train))
print(confusion_matrix(y_train, train_predictions))
print(classification_report(y_train, train_predictions))

X_test_tf_tsvd = tfidf.transform(X_test.speech)
X_test_tf_tsvd = pd.DataFrame(X_test_tf_tsvd.todense())

test_sub_pol = X_test[['subjectivity', 'polarity']].reset_index().drop(['index'], axis=1)
X_test_tf_tsvd = pd.concat([X_test_tf_tsvd, test_sub_pol], axis=1)

test_predictions = rfc.predict(X_test_tf_tsvd)
print(rfc.score(X_test_tf_tsvd, y_test))
print(confusion_matrix(y_test, test_predictions))
print(classification_report(y_test, test_predictions))
# Out:
# 0.976744186047
# [[234  13]
#  [  1 354]]
#              precision    recall  f1-score   support
#
#           0       1.00      0.95      0.97       247
#           1       0.96      1.00      0.98       355
#
# avg / total       0.98      0.98      0.98       602
#
# 0.900497512438
# [[106  35]
#  [  5 256]]
#              precision    recall  f1-score   support
#
#           0       0.95      0.75      0.84       141
#           1       0.88      0.98      0.93       261
#
# avg / total       0.91      0.90      0.90       402

# %% [markdown]
# With Truncating

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf.fit(X_train)
X_train_tf = tfidf.transform(X_train)

tsvd = TruncatedSVD(n_components=100)
tsvd.fit(X_train_tf)
X_train_tf_tsvd = tsvd.transform(X_train_tf)

rfc = RandomForestClassifier(n_estimators=100, max_depth=5)
rfc.fit(X_train_tf_tsvd, y_train)
train_predictions = rfc.predict(X_train_tf_tsvd)
print(rfc.score(X_train_tf_tsvd, y_train))
print(confusion_matrix(y_train, train_predictions))
print(classification_report(y_train, train_predictions))

X_test_tf = tfidf.transform(X_test)
X_test_tf_tsvd = tsvd.transform(X_test_tf)
test_predictions = rfc.predict(X_test_tf_tsvd)
print(rfc.score(X_test_tf_tsvd, y_test))
print(confusion_matrix(y_test, test_predictions))
print(classification_report(y_test, test_predictions))
# Out:
# 0.961794019934
# [[211  23]
#  [  0 368]]
#              precision    recall  f1-score   support
#
#           0       1.00      0.90      0.95       234
#           1       0.94      1.00      0.97       368
#
# avg / total       0.96      0.96      0.96       602
#
# 0.830845771144
# [[ 88  66]
#  [  2 246]]
#              precision    recall  f1-score   support
#
#           0       0.98      0.57      0.72       154
#           1       0.79      0.99      0.88       248
#
# avg / total       0.86      0.83      0.82       402

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(documents)
print(doc)
for token in doc:
    print(token.text, token.pos_)
# Out:
# today, from florida to mississippi, to louisiana and texas, the message once again rings loud and clear: change is coming to america.this nation is demanding for leadership that takes us in a new direction. and george  has made it clear that he's not going to provide it.george w.  is running on the slogan of ‘steady leadership.' but after four years of the same old failed policies, what we've seen is ‘stubborn leadership.'george  stubbornly proposes tax cut after tax cut for the wealthiest americans while we steadily lose millions of jobs. so tonight we say: change is coming to america.george  stubbornly refuses to help families afford health care while premiums steadily rise through the roof. and tonight we say: change is coming to america.this president stubbornly continues to let polluters rewrite our environmental laws while children steadily breathe dirtier and dirtier air. tonight we say: change is coming to america.george  stubbornly insists on a foreign policy where we go it alone and young americans in uniform steadily pay the price. and so once again tonight we say: change is coming to america.this president's stubborn leadership has steadily led america in the wrong direction – and in november, it's going to lead him out the door.we will set a new direction for america. we will build an economy that creates jobs instead of destroying them. we will finally bring health care costs under control – and at long last make health care in america a right and not a privilege. we will restore fiscal sanity. we truly will leave no child behind. we will lead america toward energy independence from mideast oil. and we will rejoin the community of nations and renew our alliances because that is essential to waging and winning the war on terror.our opponents can't campaign on jobs, health care, or fiscal responsibility. so now they say they just want to run on national security. but if george  wants to make national security the central issue of this election, i have three simple words for him i know he understands: bring it on.this president doesn't have a record to run on, only a record to run from. so his campaign has already resorted to their old tricks: attack ads and wedge politics.they don't want a great debate on the great issues. so george , who promised to be a uniter, has become the great divider.i tell you today: it won't work.in this campaign, i've been reminded of something i first learned as a young man on a navy boat on the other side of the world – the things that bring us together as americans are far more powerful than the things that pull us apart.the best lessons i learned about being an american came in a place far away from america – on a gunboat on the mekong delta with a band of brothers from all walks of life and every corner of this land. we learned many things on that journey; but above all, we learned that we were no longer the kid from south carolina or arkansas or illinois or the kid from massachusetts. the differences of color and religion and background melted away and we were united in our shared mission. we were all simply ‘americans.' all of us fighting under the same flag, praying to the same god.we learned that when we stay together – we stay strong. we didn't think we were special. we just did what we were supposed to do: fight for our country.today, 35 years later, that same principal is what guides all of us who are enlisted in this campaign: we are still fighting for our country. we always have and always will. so the message rings out tonight across our country: get ready – a new day is on the way.good night. god bless you. and may god bless the america that we love.
# today NOUN
# , PUNCT
# from ADP
# florida NOUN
# to PART
# mississippi VERB
# , PUNCT
# to ADP
# louisiana NOUN
# and CCONJ
# texas NOUN
# , PUNCT
# the DET
# message NOUN
# once ADV
# again ADV
# rings VERB
# loud ADJ
# and CCONJ
# clear ADJ
# : PUNCT
# change NOUN
# is VERB
# coming VERB
# to ADP
# america.this DET
# nation NOUN
# is VERB
# demanding VERB
# for ADP
# leadership NOUN
# that ADJ
# takes VERB
# us PRON
# in ADP
# a DET
# new ADJ
# direction NOUN
# . PUNCT
# and CCONJ
# george NOUN
#   SPACE
# has VERB
# made VERB
# it PRON
# clear ADJ
# that ADP
# he PRON
# 's VERB
# not ADV
# going VERB
# to PART
# provide VERB
# it.george NUM
# w. NOUN
#   SPACE
# is VERB
# running VERB
# on ADP
# the DET
# slogan NOUN
# of ADP
# ‘ PUNCT
# steady ADJ
# leadership NOUN
# . PUNCT
# ' PUNCT
# but CCONJ
# after ADP
# four NUM
# years NOUN
# of ADP
# the DET
# same ADJ
# old ADJ
# failed VERB
# policies NOUN
# , PUNCT
# what NOUN
# we PRON
# 've VERB
# seen VERB
# is VERB
# ‘ PUNCT
# stubborn ADJ
# leadership.'george NOUN
#   SPACE
# stubbornly ADV
# proposes VERB
# tax NOUN
# cut NOUN
# after ADP
# tax NOUN
# cut NOUN
# for ADP
# the DET
# wealthiest ADJ
# americans NOUN
# while ADP
# we PRON
# steadily ADV
# lose VERB
# millions NOUN
# of ADP
# jobs NOUN
# . PUNCT
# so ADV
# tonight NOUN
# we PRON
# say VERB
# : PUNCT
# change NOUN
# is VERB
# coming VERB
# to ADP
# america.george NOUN
#   SPACE
# stubbornly ADV
# refuses VERB
# to PART
# help VERB
# families NOUN
# afford VERB
# health NOUN
# care NOUN
# while ADP
# premiums NOUN
# steadily ADV
# rise VERB
# through ADP
# the DET
# roof NOUN
# . PUNCT
# and CCONJ
# tonight NOUN
# we PRON
# say VERB
# : PUNCT
# change NOUN
# is VERB
# coming VERB
# to ADP
# america.this DET
# president NOUN
# stubbornly ADV
# continues VERB
# to PART
# let VERB
# polluters NOUN
# rewrite VERB
# our ADJ
# environmental ADJ
# laws NOUN
# while ADP
# children NOUN
# steadily ADV
# breathe VERB
# dirtier ADJ
# and CCONJ
# dirtier ADJ
# air NOUN
# . PUNCT
# tonight NOUN
# we PRON
# say VERB
# : PUNCT
# change NOUN
# is VERB
# coming VERB
# to ADP
# america.george NOUN
#   SPACE
# stubbornly ADV
# insists VERB
# on ADP
# a DET
# foreign ADJ
# policy NOUN
# where ADV
# we PRON
# go VERB
# it PRON
# alone ADJ
# and CCONJ
# young ADJ
# americans NOUN
# in ADP
# uniform NOUN
# steadily ADV
# pay VERB
# the DET
# price NOUN
# . PUNCT
# and CCONJ
# so ADV
# once ADV
# again ADV
# tonight NOUN
# we PRON
# say VERB
# : PUNCT
# change NOUN
# is VERB
# coming VERB
# to ADP
# america.this DET
# president NOUN
# 's PART
# stubborn ADJ
# leadership NOUN
# has VERB
# steadily ADV
# led VERB
# america NOUN
# in ADP
# the DET
# wrong ADJ
# direction NOUN
# – PUNCT
# and CCONJ
# in ADP
# november NOUN
# , PUNCT
# it PRON
# 's VERB
# going VERB
# to PART
# lead VERB
# him PRON
# out PART
# the DET
# door.we NOUN
# will VERB
# set VERB
# a DET
# new ADJ
# direction NOUN
# for ADP
# america NOUN
# . PUNCT
# we PRON
# will VERB
# build VERB
# an DET
# economy NOUN
# that ADJ
# creates VERB
# jobs NOUN
# instead ADV
# of ADP
# destroying VERB
# them PRON
# . PUNCT
# we PRON
# will VERB
# finally ADV
# bring VERB
# health NOUN
# care NOUN
# costs NOUN
# under ADP
# control NOUN
# – PUNCT
# and CCONJ
# at ADP
# long ADV
# last ADJ
# make NOUN
# health NOUN
# care NOUN
# in ADP
# america NOUN
# a DET
# right NOUN
# and CCONJ
# not ADV
# a DET
# privilege NOUN
# . PUNCT
# we PRON
# will VERB
# restore VERB
# fiscal ADJ
# sanity NOUN
# . PUNCT
# we PRON
# truly ADV
# will VERB
# leave VERB
# no DET
# child NOUN
# behind ADV
# . PUNCT
# we PRON
# will VERB
# lead VERB
# america NOUN
# toward ADP
# energy NOUN
# independence NOUN
# from ADP
# mideast NOUN
# oil NOUN
# . PUNCT
# and CCONJ
# we PRON
# will VERB
# rejoin VERB
# the DET
# community NOUN
# of ADP
# nations NOUN
# and CCONJ
# renew VERB
# our ADJ
# alliances NOUN
# because ADP
# that DET
# is VERB
# essential ADJ
# to ADP
# waging VERB
# and CCONJ
# winning VERB
# the DET
# war NOUN
# on ADP
# terror.our ADJ
# opponents NOUN
# ca VERB
# n't ADV
# campaign VERB
# on ADP
# jobs NOUN
# , PUNCT
# health NOUN
# care NOUN
# , PUNCT
# or CCONJ
# fiscal ADJ
# responsibility NOUN
# . PUNCT
# so ADV
# now ADV
# they PRON
# say VERB
# they PRON
# just ADV
# want VERB
# to PART
# run VERB
# on ADP
# national ADJ
# security NOUN
# . PUNCT
# but CCONJ
# if ADP
# george NOUN
#   SPACE
# wants VERB
# to PART
# make VERB
# national ADJ
# security NOUN
# the DET
# central ADJ
# issue NOUN
# of ADP
# this DET
# election NOUN
# , PUNCT
# i PRON
# have VERB
# three NUM
# simple ADJ
# words NOUN
# for ADP
# him PRON
# i PRON
# know VERB
# he PRON
# understands VERB
# : PUNCT
# bring VERB
# it PRON
# on.this DET
# president NOUN
# does VERB
# n't ADV
# have VERB
# a DET
# record NOUN
# to PART
# run VERB
# on PART
# , PUNCT
# only ADV
# a DET
# record NOUN
# to PART
# run VERB
# from ADP
# . PUNCT
# so ADV
# his ADJ
# campaign NOUN
# has VERB
# already ADV
# resorted VERB
# to ADP
# their ADJ
# old ADJ
# tricks NOUN
# : PUNCT
# attack NOUN
# ads NOUN
# and CCONJ
# wedge NOUN
# politics.they PRON
# do VERB
# n't ADV
# want VERB
# a DET
# great ADJ
# debate NOUN
# on ADP
# the DET
# great ADJ
# issues NOUN
# . PUNCT
# so ADV
# george NOUN
# , PUNCT
# who NOUN
# promised VERB
# to PART
# be VERB
# a DET
# uniter NOUN
# , PUNCT
# has VERB
# become VERB
# the DET
# great ADJ
# divider.i NOUN
# tell VERB
# you PRON
# today NOUN
# : PUNCT
# it PRON
# wo VERB
# n't ADV
# work.in VERB
# this DET
# campaign NOUN
# , PUNCT
# i PRON
# 've VERB
# been VERB
# reminded VERB
# of ADP
# something NOUN
# i PRON
# first ADV
# learned VERB
# as ADP
# a DET
# young ADJ
# man NOUN
# on ADP
# a DET
# navy NOUN
# boat NOUN
# on ADP
# the DET
# other ADJ
# side NOUN
# of ADP
# the DET
# world NOUN
# – PUNCT
# the DET
# things NOUN
# that ADJ
# bring VERB
# us PRON
# together ADV
# as ADP
# americans NOUN
# are VERB
# far ADV
# more ADV
# powerful ADJ
# than ADP
# the DET
# things NOUN
# that ADJ
# pull VERB
# us PRON
# apart.the DET
# best ADJ
# lessons NOUN
# i PRON
# learned VERB
# about ADP
# being VERB
# an DET
# american ADJ
# came VERB
# in ADP
# a DET
# place NOUN
# far ADV
# away ADV
# from ADP
# america NOUN
# – PUNCT
# on ADP
# a DET
# gunboat NOUN
# on ADP
# the DET
# mekong NOUN
# delta NOUN
# with ADP
# a DET
# band NOUN
# of ADP
# brothers NOUN
# from ADP
# all DET
# walks NOUN
# of ADP
# life NOUN
# and CCONJ
# every DET
# corner NOUN
# of ADP
# this DET
# land NOUN
# . PUNCT
# we PRON
# learned VERB
# many ADJ
# things NOUN
# on ADP
# that DET
# journey NOUN
# ; PUNCT
# but CCONJ
# above ADP
# all DET
# , PUNCT
# we PRON
# learned VERB
# that ADP
# we PRON
# were VERB
# no ADV
# longer ADV
# the DET
# kid NOUN
# from ADP
# south ADJ
# carolina NOUN
# or CCONJ
# arkansas NOUN
# or CCONJ
# illinois NOUN
# or CCONJ
# the DET
# kid NOUN
# from ADP
# massachusetts NOUN
# . PUNCT
# the DET
# differences NOUN
# of ADP
# color NOUN
# and CCONJ
# religion NOUN
# and CCONJ
# background NOUN
# melted VERB
# away ADV
# and CCONJ
# we PRON
# were VERB
# united VERB
# in ADP
# our ADJ
# shared ADJ
# mission NOUN
# . PUNCT
# we PRON
# were VERB
# all ADV
# simply ADV
# ‘ NUM
# americans NOUN
# . PUNCT
# ' PUNCT
# all DET
# of ADP
# us PRON
# fighting VERB
# under ADP
# the DET
# same ADJ
# flag NOUN
# , PUNCT
# praying VERB
# to ADP
# the DET
# same ADJ
# god.we PROPN
# learned VERB
# that ADP
# when ADV
# we PRON
# stay VERB
# together ADV
# – PUNCT
# we PRON
# stay VERB
# strong ADJ
# . PUNCT
# we PRON
# did VERB
# n't ADV
# think VERB
# we PRON
# were VERB
# special ADJ
# . PUNCT
# we PRON
# just ADV
# did VERB
# what NOUN
# we PRON
# were VERB
# supposed VERB
# to PART
# do VERB
# : PUNCT
# fight VERB
# for ADP
# our ADJ
# country.today NOUN
# , PUNCT
# 35 NUM
# years NOUN
# later ADV
# , PUNCT
# that DET
# same ADJ
# principal NOUN
# is VERB
# what NOUN
# guides VERB
# all DET
# of ADP
# us PRON
# who NOUN
# are VERB
# enlisted VERB
# in ADP
# this DET
# campaign NOUN
# : PUNCT
# we PRON
# are VERB
# still ADV
# fighting VERB
# for ADP
# our ADJ
# country NOUN
# . PUNCT
# we PRON
# always ADV
# have VERB
# and CCONJ
# always ADV
# will VERB
# . PUNCT
# so ADV
# the DET
# message NOUN
# rings VERB
# out PART
# tonight NOUN
# across ADP
# our ADJ
# country NOUN
# : PUNCT
# get VERB
# ready ADJ
# – PUNCT
# a DET
# new ADJ
# day NOUN
# is VERB
# on ADP
# the DET
# way.good ADJ
# night NOUN
# . PUNCT
# god INTJ
# bless VERB
# you PRON
# . PUNCT
# and CCONJ
# may VERB
# god VERB
# bless VERB
# the DET
# america NOUN
# that ADJ
# we PRON
# love VERB
# . PUNCT

# %%
documents
# Out:
# "today, from florida to mississippi, to louisiana and texas, the message once again rings loud and clear: change is coming to america.this nation is demanding for leadership that takes us in a new direction. and george  has made it clear that he's not going to provide it.george w.  is running on the slogan of ‘steady leadership.' but after four years of the same old failed policies, what we've seen is ‘stubborn leadership.'george  stubbornly proposes tax cut after tax cut for the wealthiest americans while we steadily lose millions of jobs. so tonight we say: change is coming to america.george  stubbornly refuses to help families afford health care while premiums steadily rise through the roof. and tonight we say: change is coming to america.this president stubbornly continues to let polluters rewrite our environmental laws while children steadily breathe dirtier and dirtier air. tonight we say: change is coming to america.george  stubbornly insists on a foreign policy where we go it alone and young americans in uniform steadily pay the price. and so once again tonight we say: change is coming to america.this president's stubborn leadership has steadily led america in the wrong direction – and in november, it's going to lead him out the door.we will set a new direction for america. we will build an economy that creates jobs instead of destroying them. we will finally bring health care costs under control – and at long last make health care in america a right and not a privilege. we will restore fiscal sanity. we truly will leave no child behind. we will lead america toward energy independence from mideast oil. and we will rejoin the community of nations and renew our alliances because that is essential to waging and winning the war on terror.our opponents can't campaign on jobs, health care, or fiscal responsibility. so now they say they just want to run on national security. but if george  wants to make national security the central issue of this election, i have three simple words for him i know he understands: bring it on.this president doesn't have a record to run on, only a record to run from. so his campaign has already resorted to their old tricks: attack ads and wedge politics.they don't want a great debate on the great issues. so george , who promised to be a uniter, has become the great divider.i tell you today: it won't work.in this campaign, i've been reminded of something i first learned as a young man on a navy boat on the other side of the world – the things that bring us together as americans are far more powerful than the things that pull us apart.the best lessons i learned about being an american came in a place far away from america – on a gunboat on the mekong delta with a band of brothers from all walks of life and every corner of this land. we learned many things on that journey; but above all, we learned that we were no longer the kid from south carolina or arkansas or illinois or the kid from massachusetts. the differences of color and religion and background melted away and we were united in our shared mission. we were all simply ‘americans.' all of us fighting under the same flag, praying to the same god.we learned that when we stay together – we stay strong. we didn't think we were special. we just did what we were supposed to do: fight for our country.today, 35 years later, that same principal is what guides all of us who are enlisted in this campaign: we are still fighting for our country. we always have and always will. so the message rings out tonight across our country: get ready – a new day is on the way.good night. god bless you. and may god bless the america that we love."

# %%
cv = CountVectorizer()
cv.fit(X_train.speech)
X_train_v = cv.transform(X_train.speech)

feature_names = cv.get_feature_names()

lda = LatentDirichletAllocation(n_components=5)
lda.fit(X_train_v)
# Out:
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7, learning_method=None,
#              learning_offset=10.0, max_doc_update_iter=100, max_iter=10,
#              mean_change_tol=0.001, n_components=5, n_jobs=1,
#              n_topics=None, perp_tol=0.1, random_state=None,
#              topic_word_prior=None, total_samples=1000000.0, verbose=0)

# %%
results = pd.DataFrame(lda.components_, columns=feature_names)


results.loc['mean'] = results.mean()
# results.loc[['mean']]
results = results.transpose()

# %%
results[['mean']].loc[results['mean'] > 100]
# Out:
#                         mean
# 000               216.904627
# able              198.869541
# about            1205.669817
# across            196.411202
# act               107.355483
# actually          146.698238
# administration    151.396315
# afford            135.423096
# afghanistan       116.468300
# after             281.110257
# again             313.865801
# against           228.450556
# ago               172.650514
# all              1347.402157
# also              454.458604
# always            192.869148
# am                310.255019
# america          1268.560498
# american          805.668580
# americans         519.549988
# an                866.711854
# and             12414.121584
# another           183.536919
# any               262.848329
# applause          862.382937
# are              2361.091513
# around            194.155458
# as               1619.774490
# ask               146.592746
# at               1044.440569
# audience          112.194680
# away              120.072256
# back              511.801055
# be               1886.616830
# because           973.679715
# been              761.970751
# before            259.251016
# being             236.718994
# believe           492.677695
# best              228.777005
# better            329.023646
# between           146.125131
# big               187.888456
# bill              144.491430
# billion           156.697998
# both              137.189696
# bring             171.759633
# build             140.339276
# business          237.683598
# businesses        184.285684
# but              1698.190329
# by               1041.537736
# called            123.078059
# came              143.277923
# campaign          307.006868
# can              1471.723510
# cannot            136.827052
# care              546.614511
# century           112.568928
# challenges        109.769405
# chance            144.850019
# change            369.872489
# cheers            129.182619
# child             155.003748
# children          297.131337
# choice            154.167757
# class             200.978855
# clear             129.569549
# college           193.121379
# come              314.298716
# comes             115.499738
# coming            133.159049
# community         134.782627
# companies         193.741271
# congress          169.906624
# continue          120.352515
# cost              121.994050
# costs             112.000725
# could             308.134200
# countries         132.265134
# country           946.704637
# course            133.043159
# create            192.291254
# crisis            171.995890
# cut               150.819785
# day               307.710190
# days              151.636035
# deal              107.888794
# did               265.403702
# didn              200.832725
# different         148.012636
# do               1313.778094
# does              126.949840
# doesn             160.321245
# doing             195.740794
# dollars           134.487852
# don               652.713104
# done              222.397311
# down              302.091577
# each              141.879141
# economic          232.486276
# economy           470.357366
# education         208.480783
# election          254.100995
# end               221.213040
# energy            314.072916
# enough            137.045683
# even              328.164808
# ever              179.974924
# every             581.846616
# everybody         181.653176
# everything        129.201180
# face              138.965564
# fact              134.093708
# faith             106.227829
# families          331.488877
# family            223.043450
# federal           145.029301
# few               138.423294
# fight             185.886855
# fighting          111.935688
# finally           119.729633
# find              134.788584
# first             383.852592
# folks             129.847749
# for              3736.478379
# foreign           114.698304
# forward           113.010365
# four              259.616085
# free              148.108085
# freedom           133.042269
# friends           147.507800
# from             1058.304034
# future            268.464208
# george            104.013009
# get               769.343212
# getting           140.234114
# give              299.313778
# go                449.995098
# god               136.253969
# going            1314.357671
# good              452.350723
# got               530.179814
# government        462.629574
# great             467.434521
# had               587.966287
# happen            109.037135
# hard              291.811852
# has               975.353512
# have             2805.595112
# he               1486.469838
# health            455.148357
# help              448.811416
# her               325.375402
# here              742.861610
# high              150.435233
# hillary           166.465800
# him               235.023982
# his               555.426018
# history           153.436540
# home              288.697128
# hope              181.650488
# house             138.052047
# how               604.657565
# if               1000.433089
# important         207.869617
# in               6151.519220
# instead           112.192999
# insurance         135.970711
# into              369.805795
# iraq              345.777583
# is               3656.612392
# issue             117.458781
# issues            108.198140
# it               3817.434292
# its               199.633984
# job               277.754592
# jobs              642.806118
# john              126.334820
# just              861.502326
# keep              292.075552
# kids              157.388838
# kind              193.835697
# know             1158.266140
# last              351.794464
# laughter          244.737997
# law               136.166413
# lead              135.831862
# leadership        129.092192
# left              108.134415
# less              133.134158
# let               412.898696
# life              237.514890
# like              590.680579
# little            152.357297
# live              104.330690
# lives             141.931292
# ll                486.502368
# long              234.504467
# look              271.407815
# lost              140.693656
# lot               330.768671
# love              146.030123
# made              288.523053
# make              939.105804
# making            215.777587
# man               120.266508
# many              464.883559
# matter            117.395693
# may               145.970971
# me                740.500861
# mean              140.153775
# means             156.915277
# meet              107.291870
# men               127.838998
# middle            249.547769
# might             100.680021
# military          189.106651
# million           245.933353
# millions          132.084261
# money             251.468025
# months            104.724927
# more             1259.154514
# most              318.777037
# much              340.972294
# must              299.473789
# my               1173.427571
# nation            288.539980
# national          186.903064
# need              688.361903
# never             290.310408
# new               676.570238
# next              232.592330
# no                585.135897
# not              1827.331908
# nothing           109.737212
# now               765.473186
# nuclear           123.516594
# number            111.174957
# of               7960.992774
# off               155.833777
# office            122.789833
# oil               166.645764
# old               106.022686
# on               2123.147044
# once              119.879873
# one               898.460997
# only              324.858635
# opponent          105.540391
# opportunity       161.320215
# or               1014.843601
# other             449.726903
# our              3292.120370
# out               754.428377
# over              426.126230
# own               282.307611
# part              206.684434
# party             109.964894
# past              110.131383
# pay               282.535995
# people           1579.655926
# percent           188.229645
# place             176.664168
# plan              334.053297
# policies          124.981106
# policy            128.834627
# political         134.679564
# politics          111.067979
# power             151.431372
# president        1046.749458
# problem           119.494347
# problems          122.409451
# promise           110.902945
# protect           106.943863
# proud             101.398578
# provide           130.860011
# public            130.850290
# put               291.358575
# question          151.466663
# raise             100.530270
# re               1425.188827
# real              157.393217
# really            241.437865
# reform            119.688352
# remember          111.373179
# right             565.831185
# rights            110.922670
# running           167.593412
# said              605.417449
# same              299.218165
# say               391.200856
# saying            106.475599
# says              119.040187
# school            194.505092
# schools           137.296814
# second            100.377815
# security          288.078060
# see               364.794232
# seen              165.267754
# senator           393.860511
# sense             106.319378
# service           101.280993
# set               112.697545
# she               475.175018
# should            425.849461
# since             152.681664
# single            131.094282
# small             238.071662
# so               1496.558957
# some              565.940540
# something         211.490436
# spending          122.395491
# stand             175.688154
# start             182.682820
# state             243.012592
# states            396.635126
# still             266.241240
# stop              121.920955
# street            133.050506
# strong            164.495633
# support           217.061001
# sure              381.648729
# system            198.309118
# take              426.138236
# talk              185.642869
# talking           125.091020
# tax               443.413403
# taxes             222.923979
# tell              255.878127
# than              605.166328
# thank             446.802620
# that             7474.750338
# the             15275.576497
# their            1244.819124
# them              760.455996
# then              355.317472
# there            1016.921925
# these             519.947138
# they             2105.985427
# thing             173.453053
# things            245.773259
# think             750.975826
# this             2525.829658
# those             603.452431
# three             137.387039
# through           224.573896
# time              699.166744
# times             155.611370
# to              12216.565894
# today             397.331988
# together          338.448418
# too               252.594339
# tough             113.170385
# trade             146.682706
# troops            141.565156
# try               110.323935
# trying            107.833374
# turn              100.909421
# two               239.796775
# under             151.444867
# understand        157.182968
# united            344.182792
# up                812.552079
# us                919.601126
# use               135.406713
# values            139.526735
# ve               1066.043259
# very              459.614737
# vote              209.043665
# wall              117.634003
# want              853.414217
# wants             110.407585
# war               368.043116
# was              1360.395681
# washington        240.361608
# way               443.755088
# we               6740.568797
# well              524.345945
# went              115.878487
# were              567.391408
# what             1530.173020
# when             1093.862400
# where             427.933876
# whether           137.404579
# which             325.151627
# while             143.593246
# white             112.959941
# who              1533.395839
# why               376.868421
# will             1989.040801
# win               170.087857
# with             1814.406987
# without           141.620872
# women             239.786777
# won               177.642707
# work              658.241094
# worked            107.823820
# workers           201.434992
# working           267.172047
# world             622.429308
# would             665.445466
# wrong             136.145143
# year              306.130746
# years             695.589147
# yes               137.932415
# you              4353.835744
# young             201.802909
# your              980.248192
