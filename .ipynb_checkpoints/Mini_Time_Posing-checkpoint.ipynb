# %% [markdown]
# # Modeling One

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
df_2004 = pd.read_csv('./csv_files/df_2004')
df_2008 = pd.read_csv('./csv_files/df_2008')
df_2012 = pd.read_csv('./csv_files/df_2012')
df_2016 = pd.read_csv('./csv_files/df_2016')

# %%
df_2008['previous_year_total'] = np.log(df_2004['total_vote_ratio'])
df_2008['previous_year_dem'] = np.log(df_2004['dem_vote_ratio'])
df_2008['previous_year_rep'] = np.log(df_2004['rep_vote_ratio'])
df_2008['previous_year_dif'] = df_2004['vote_diff']

df_2008['total_diff'] = df_2008['total_vote_ratio'] - df_2008['previous_year_total']
df_2008['dem_diff'] = df_2008['dem_vote_ratio'] - df_2008['previous_year_dem']
df_2008['rep_diff'] = df_2008['rep_vote_ratio'] - df_2008['previous_year_rep']
df_2008['diff_diff'] = df_2008['vote_diff'] - df_2008['previous_year_dif']


df_2012['previous_year_total'] = np.log(df_2008['total_vote_ratio'])
df_2012['previous_year_dem'] = np.log(df_2008['dem_vote_ratio'])
df_2012['previous_year_rep'] = np.log(df_2008['rep_vote_ratio'])
df_2012['previous_year_dif'] = df_2008['vote_diff']

df_2012['total_diff'] = df_2012['total_vote_ratio'] - df_2012['previous_year_total']
df_2012['dem_diff'] = df_2012['dem_vote_ratio'] - df_2012['previous_year_dem']
df_2012['rep_diff'] = df_2012['rep_vote_ratio'] - df_2012['previous_year_rep']
df_2012['diff_diff'] = df_2012['vote_diff'] - df_2012['previous_year_dif']


df_2016['previous_year_total'] = np.log(df_2012['total_vote_ratio'])
df_2016['previous_year_dem'] = np.log(df_2012['dem_vote_ratio'])
df_2016['previous_year_rep'] = np.log(df_2012['rep_vote_ratio'])
df_2016['previous_year_dif'] = df_2012['vote_diff']

df_2016['total_diff'] = df_2016['total_vote_ratio'] - df_2016['previous_year_total']
df_2016['dem_diff'] = df_2016['dem_vote_ratio'] - df_2016['previous_year_dem']
df_2016['rep_diff'] = df_2016['rep_vote_ratio'] - df_2016['previous_year_rep']
df_2016['diff_diff'] = df_2016['vote_diff'] - df_2016['previous_year_dif']

# %% [markdown]
# # Linear Model

# %%
df_2008.head()
# Out:
#    oct_rate  nov_rate   density  per_pov  med_income  total_vote_ratio  \
# 0       8.8       8.9  0.019768     17.6       36041          0.420639
# 1       4.5       4.5  0.010722     19.7       37862          0.429616
# 2       4.7       5.2  0.013401     20.6       37564          0.454519
# 3       5.7       6.6  0.002757      9.0       57159          0.457119
# 4       3.3       3.6  0.073487     10.0       44824          0.513618
#
#    dem_vote_ratio  rep_vote_ratio  vote_diff  continuum_2003    ...      \
# 0        0.178451        0.242188  -0.063738               6    ...
# 1        0.114996        0.314620  -0.199624               4    ...
# 2        0.223933        0.230586  -0.006653               7    ...
# 3        0.214373        0.242746  -0.028373               2    ...
# 4        0.247838        0.265780  -0.017942               8    ...
#
#    per_some_college_change  per_bachelors_change  previous_year_total  \
# ...

# %%
def linear_model(df, target):
    
    if target == 'total_vote_ratio' or target == 'total_diff':
        X = df.drop(['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff', 
                     'previous_year_dem', 'previous_year_rep', 'previous_year_dif', 
                     'total_diff', 'dem_diff', 'rep_diff', 'diff_diff'], axis=1)
    elif target == 'dem_vote_ratio' or target == 'dem_diff':
        X = df.drop(['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff',
                     'previous_year_total', 'previous_year_rep', 'previous_year_dif', 
                     'total_diff', 'dem_diff', 'rep_diff', 'diff_diff'], axis=1)       
    elif target == 'rep_vote_ratio' or target == 'rep_diff':
        X = df.drop(['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff',
                     'previous_year_total', 'previous_year_dem', 'previous_year_dif', 
                     'total_diff', 'dem_diff', 'rep_diff', 'diff_diff'], axis=1)
    elif target == 'vote_diff' or target == 'diff_diff':
        X = df.drop(['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff',
                     'previous_year_total', 'previous_year_dem', 'previous_year_rep', 
                     'total_diff', 'dem_diff', 'rep_diff', 'diff_diff'], axis=1)
        
    y = df[target]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

    ss = StandardScaler()
    X_train = ss.fit_transform(X_train)
    X_test = ss.transform(X_test)
    
    lm = LinearRegression()
    lm.fit(X_train, y_train)
    
    print('R^2 on train', lm.score(X_train, y_train).mean())
    print('R^2 on test', cross_val_score(lm, X_test, y_test, cv=5).mean())
    
    predictions = lm.predict(X_test)
    
    print('mean squared error', np.sqrt(mean_squared_error(y_test, predictions)))
    
    if target == 'total_vote_ratio' or target == 'total_diff':
        color = 'rebeccapurple'
    elif target == 'dem_vote_ratio' or target == 'dem_diff':
        color = 'cornflowerblue'
    elif target == 'rep_vote_ratio' or target == 'rep_diff':
        color = 'firebrick'
    else:
        color = 'forestgreen'
    
    plt.scatter(y_test, predictions, alpha=.1, color=color)
    plt.title('Predictions versus Actual');
    plt.show()
    
    residuals = y_test - lm.predict(X_test)
    
    plt.scatter(y_test, residuals, alpha=.1, color=color)
    plt.title('Residuals');
    plt.show()
    
    plt.hist(residuals, bins=25, color=color)
    plt.title("Histogram of Residuals");
    
    columns = []
    for x in X.columns:
        columns.append(x)
    
    feature_importance = pd.DataFrame()
    feature_importance['feature_name'] = columns
    feature_importance['coefficients'] = lm.coef_

    
    fig, ax = plt.subplots()
    fig.set_size_inches(10, 10)
#     plt.xlim(-0.2, 0.2)

    people = feature_importance['feature_name']
    y_pos = np.arange(len(people))
    performance = feature_importance['coefficients']


    ax.barh(y_pos, performance, align='center', color=color)
    ax.set_yticks(y_pos)
    ax.set_yticklabels(people)
    ax.invert_yaxis() 
    plt.title('Feature Importance')
    plt.show()

# %% [markdown]
# # 2008

# %%
linear_model(df_2008, 'total_vote_ratio')
# Out:
# R^2 on train 0.765334954016
# R^2 on test 0.801142671664
# mean squared error 0.0340181911192

# %%
linear_model(df_2008, 'dem_vote_ratio')
# Out:
# R^2 on train 0.819311558277
# R^2 on test 0.827458974526
# mean squared error 0.0304352624765

# %%
linear_model(df_2008, 'rep_vote_ratio')
# Out:
# R^2 on train 0.838292372171
# R^2 on test 0.832335459495
# mean squared error 0.0282788577671

# %%
linear_model(df_2008, 'vote_diff')
# Out:
# R^2 on train 0.904344694543
# R^2 on test 0.897761257601
# mean squared error 0.0383169461969

# %% [markdown]
# # 2012

# %%
linear_model(df_2012, 'total_vote_ratio')
# Out:
# R^2 on train 0.843537144622
# R^2 on test 0.866092422371
# mean squared error 0.0306531974562

# %%
linear_model(df_2012, 'dem_vote_ratio')
# Out:
# R^2 on train 0.872307340756
# R^2 on test 0.85843256278
# mean squared error 0.0283999158428

# %%
linear_model(df_2012, 'rep_vote_ratio')
# Out:
# R^2 on train 0.876302119408
# R^2 on test 0.868815636628
# mean squared error 0.0273570518634

# %%
linear_model(df_2012, 'vote_diff')
# Out:
# R^2 on train 0.958618215626
# R^2 on test 0.955605148496
# mean squared error 0.0265587046105

# %% [markdown]
# # 2016

# %%
linear_model(df_2016, 'total_vote_ratio')
# Out:
# R^2 on train 0.882405261012
# R^2 on test 0.859128209594
# mean squared error 0.0299317635524

# %%
linear_model(df_2016, 'dem_vote_ratio')
# Out:
# R^2 on train 0.882147812227
# R^2 on test 0.870597353065
# mean squared error 0.0252793888447

# %%
linear_model(df_2016, 'rep_vote_ratio')
# Out:
# R^2 on train 0.889517363449
# R^2 on test 0.858620834083
# mean squared error 0.0323312556575

# %%
linear_model(df_2016, 'vote_diff')
# Out:
# R^2 on train 0.954550613986
# R^2 on test 0.949527176242
# mean squared error 0.029778771242

# %% [markdown]
# # Random Forest

# %%
# possible targets ['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff']
    
def forest_model(df, target):
    
    if target == 'total_vote_ratio' or target == 'total_diff':
        X = df.drop(['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff', 
                     'previous_year_dem', 'previous_year_rep', 'previous_year_dif', 
                     'total_diff', 'dem_diff', 'rep_diff', 'diff_diff'], axis=1)
    elif target == 'dem_vote_ratio' or target == 'dem_diff':
        X = df.drop(['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff',
                     'previous_year_total', 'previous_year_rep', 'previous_year_dif', 
                     'total_diff', 'dem_diff', 'rep_diff', 'diff_diff'], axis=1)       
    elif target == 'rep_vote_ratio' or target == 'rep_diff':
        X = df.drop(['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff',
                     'previous_year_total', 'previous_year_dem', 'previous_year_dif', 
                     'total_diff', 'dem_diff', 'rep_diff', 'diff_diff'], axis=1)
    elif target == 'vote_diff' or target == 'diff_diff':
        X = df.drop(['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff',
                     'previous_year_total', 'previous_year_dem', 'previous_year_rep', 
                     'total_diff', 'dem_diff', 'rep_diff', 'diff_diff'], axis=1)


    y = df[target]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=27)

    ss = StandardScaler()
    X_train = ss.fit_transform(X_train)
    X_test = ss.transform(X_test)
    
    rf = RandomForestRegressor(n_estimators=50, max_features=10, max_depth=10, min_samples_leaf=10)
    rf.fit(X_train, y_train)
    
    print('R^2 on train', rf.score(X_train, y_train).mean())
    print('R^2 on test', cross_val_score(rf, X_test, y_test, cv=5).mean())
    
    predictions = rf.predict(X_test)
    
    print('mean squared error', np.sqrt(mean_squared_error(y_test, predictions)))
    
    if target == 'total_vote_ratio' or target == 'total_diff':
        color = 'rebeccapurple'
    elif target == 'dem_vote_ratio' or target == 'dem_diff':
        color = 'cornflowerblue'
    elif target == 'rep_vote_ratio' or target == 'rep_diff':
        color = 'firebrick'
    else:
        color = 'forestgreen'
    
    plt.scatter(y_train, rf.predict(X_train), alpha=.1, color=color)
    plt.title('Predictions versus Actual Train');
    plt.show()
    
    plt.scatter(y_test, predictions, alpha=.1, color=color)
    plt.title('Predictions versus Actual Test');
    plt.show()
    
    residuals = y_test - rf.predict(X_test)
    
    plt.scatter(y_test, residuals, alpha=.1, color=color)
    plt.title('Residuals');
    plt.show()
    
    plt.hist(residuals, bins=25, color=color)
    plt.title("Histogram of Residuals");
    
    columns = []
    for x in X.columns:
        columns.append(x)
    
    feature_importance = pd.DataFrame()
    feature_importance['feature_name'] = columns
    feature_importance['features'] = rf.feature_importances_

    
    fig, ax = plt.subplots()
    fig.set_size_inches(10, 10)
#     plt.xlim(-0.2, 0.2)

    people = feature_importance['feature_name']
    y_pos = np.arange(len(people))
    performance = feature_importance['features']


    ax.barh(y_pos, performance, align='center', color=color)
    ax.set_yticks(y_pos)
    ax.set_yticklabels(people)
    ax.invert_yaxis() 
    plt.title('Feature Importance')
    plt.show()

# %% [markdown]
# ## 2008

# %%
forest_model(df_2008, 'total_vote_ratio')
# Out:
# R^2 on train 0.858740765021
# R^2 on test 0.783414703275
# mean squared error 0.0333056884309

# %%
forest_model(df_2008, 'dem_vote_ratio')
# Out:
# R^2 on train 0.914042806111
# R^2 on test 0.859427108826
# mean squared error 0.0256815229254

# %%
forest_model(df_2008, 'rep_vote_ratio')
# Out:
# R^2 on train 0.923581428989
# R^2 on test 0.869994732324
# mean squared error 0.0231332319413

# %%
forest_model(df_2008, 'vote_diff')
# Out:
# R^2 on train 0.940676082933
# R^2 on test 0.897354175028
# mean squared error 0.0348212540589

# %% [markdown]
# ## 2012

# %%
forest_model(df_2012, 'total_vote_ratio')
# Out:
# R^2 on train 0.915995470555
# R^2 on test 0.866126238555
# mean squared error 0.0269007786889

# %%
forest_model(df_2012, 'dem_vote_ratio')
# Out:
# R^2 on train 0.95854888894
# R^2 on test 0.927268705231
# mean squared error 0.0184582101763

# %%
forest_model(df_2012, 'rep_vote_ratio')
# Out:
# R^2 on train 0.948351062317
# R^2 on test 0.917415226233
# mean squared error 0.0200662735707

# %%
forest_model(df_2012, 'vote_diff')
# Out:
# R^2 on train 0.966855271097
# R^2 on test 0.944575735432
# mean squared error 0.0267820398234

# %% [markdown]
# ## 2016

# %%
forest_model(df_2016, 'total_vote_ratio')
# Out:
# R^2 on train 0.922592146754
# R^2 on test 0.856170072579
# mean squared error 0.0272035286864

# %%
forest_model(df_2012, 'dem_vote_ratio')
# Out:
# R^2 on train 0.960073059645
# R^2 on test 0.927187829093
# mean squared error 0.0182051642588

# %%
forest_model(df_2012, 'rep_vote_ratio')
# Out:
# R^2 on train 0.947174433655
# R^2 on test 0.917026482067
# mean squared error 0.0201594351442

# %%
forest_model(df_2012, 'vote_diff')
# Out:
# R^2 on train 0.966224308392
# R^2 on test 0.944915466985
# mean squared error 0.0269327908353
