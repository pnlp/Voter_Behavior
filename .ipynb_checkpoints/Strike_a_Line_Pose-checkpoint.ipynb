# %% [markdown]
# # Linear Modeling
#
# This notebook uses the voter data to predicted the voter turnout for each country during each election separately.
# Two models are show here.
# - [Linear Regression](#section1)
# - [Gradient Boost Regression](#section2)

# %% [markdown]
# ### Previous Notebook [Exploratory Data Analysis](EDA.ipybnb)
# ### Next Notebook [Mini Time Series Modeling](Mini_Time_Posing.ipynb)

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %matplotlib inline

from sklearn.linear_model import LinearRegression, ElasticNetCV, LassoCV, RidgeCV
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
df_2004 = pd.read_csv('./csv_files/df_2004')
df_2008 = pd.read_csv('./csv_files/df_2008')
df_2012 = pd.read_csv('./csv_files/df_2012')
df_2016 = pd.read_csv('./csv_files/df_2016')

# %%
df_2004.head()
# Out:
#    oct_rate  nov_rate   density  per_pov  med_income  total_vote_ratio  \
# 0       7.8       8.3  0.019365     15.1       31362          0.374462
# 1       5.3       5.3  0.011065     21.0       30040          0.422471
# 2       4.0       4.6  0.012538     14.9       31256          0.364665
# 3       3.9       3.9  0.003150      9.1       50754          0.454130
# 4       3.5       3.7  0.070994      9.7       41406          0.526998
#
#    dem_vote_ratio  rep_vote_ratio  vote_diff  continuum_2003  influence_2003  \
# 0        0.167296        0.207166  -0.039870               6               6
# 1        0.150904        0.271567  -0.120663               4               5
# 2        0.151942        0.212724  -0.060782               7               9
# 3        0.173859        0.280271  -0.106412               2               2
# 4        0.228582        0.298416  -0.069834               8               7
#
#    per_less_high_2000  per_high_diploma_2000  per_some_college_2000  \
# 0                29.9                   35.9                   21.4
# 1                35.3                   38.0                   17.2
# 2                32.1                   34.1                   20.3
# 3                 9.2                   23.1                   36.5
# 4                12.2                   48.4                   28.2
#
#    per_bachelors_or_higher_2000  per_less_high_change  \
# 0                          12.8                 -11.2
# 1                           9.4                 -10.1
# 2                          13.5                  -8.4
# 3                          31.2                  -3.6
# 4                          11.2                 -10.3
#
#    per_high_dimploma_change  per_some_college_change  per_bachelors_change
# 0                       2.5                      6.7                   2.0
# 1                       4.5                      4.6                   1.0
# 2                       0.6                      3.5                   4.3
# 3                      -2.9                      0.2                   6.3
# 4                       3.0                      6.0                   1.4

# %% [markdown]
# <a id='section1'></a>
# # Linear Modeling

# %%
# possible targets ['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff']
def linear_model(df, target):
    X = df.drop(['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff'], axis=1)
    y = df[target]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

    ss = StandardScaler()
    X_train = ss.fit_transform(X_train)
    X_test = ss.transform(X_test)
    
    lm = LinearRegression()
    lm.fit(X_train, y_train)
    
    print('R^2', lm.score(X_train, y_train))
    print('R^2', cross_val_score(lm, X_test, y_test).mean())
    
    predictions = lm.predict(X_test)
    
    print('mean squared error', np.sqrt(mean_squared_error(y_test, predictions)))
    
    if target == 'total_vote_ratio':
        color = 'rebeccapurple'
    elif target == 'dem_vote_ratio':
        color = 'cornflowerblue'
    elif target == 'rep_vote_ratio':
        color = 'firebrick'
    else:
        color = 'forestgreen'
    
    plt.scatter(y_test, predictions, alpha=.1, color=color)
    plt.title('Predictions versus Actual');
    plt.show()
    
    residuals = y_test - lm.predict(X_test)
    
    plt.scatter(y_test, residuals, alpha=.1, color=color)
    plt.title('Residuals');
    plt.show()
    
    plt.hist(residuals, bins=25, color=color)
    plt.title("Histogram of Residuals");
    
    columns = []
    for x in X.columns:
        columns.append(x + '[{}]' .format(target))
    
    feature_importance = pd.DataFrame()
    feature_importance['feature_name'] = columns
    feature_importance['coefficients'] = lm.coef_

    
    fig, ax = plt.subplots()
    fig.set_size_inches(10, 10)
    plt.xlim(-0.6, 0.6)

    people = feature_importance['feature_name']
    y_pos = np.arange(len(people))
    performance = feature_importance['coefficients']


    ax.barh(y_pos, performance, align='center', color=color)
    ax.set_yticks(y_pos)
    ax.set_yticklabels(people)
    ax.invert_yaxis() 
    plt.show()

# %% [markdown]
# # 2004

# %%
linear_model(df_2004, 'total_vote_ratio')
# Out:
# R^2 0.491664361713
# R^2 0.505176510536
# mean squared error 0.0554586520087

# %%
linear_model(df_2004, 'dem_vote_ratio')
# Out:
# R^2 0.24401432957
# R^2 0.219226763004
# mean squared error 0.0562970607309

# %%
linear_model(df_2004, 'rep_vote_ratio')
# Out:
# R^2 0.541071643656
# R^2 0.509786891661
# mean squared error 0.0497455714277

# %%
linear_model(df_2004, 'vote_diff')
# Out:
# R^2 0.383342709637
# R^2 0.326165764446
# mean squared error 0.0906217400219

# %% [markdown]
# # 2008

# %%
linear_model(df_2008, 'total_vote_ratio')
# Out:
# R^2 0.432106381231
# R^2 0.490087934444
# mean squared error 0.0563080012867

# %%
linear_model(df_2008, 'dem_vote_ratio')
# Out:
# R^2 0.295606453378
# R^2 0.299014666546
# mean squared error 0.0614572031667

# %%
linear_model(df_2008, 'rep_vote_ratio')
# Out:
# R^2 0.453808960227
# R^2 0.433182041958
# mean squared error 0.0520534335405

# %%
linear_model(df_2008, 'vote_diff')
# Out:
# R^2 0.351154242575
# R^2 0.30950805169
# mean squared error 0.0990075982941

# %% [markdown]
# # 2012

# %%
linear_model(df_2012, 'total_vote_ratio')
# Out:
# R^2 0.360847761967
# R^2 0.39900294264
# mean squared error 0.064506003354

# %%
linear_model(df_2012, 'dem_vote_ratio')
# Out:
# R^2 0.268139744356
# R^2 0.263282880867
# mean squared error 0.0653423976474

# %%
linear_model(df_2012, 'rep_vote_ratio')
# Out:
# R^2 0.440587737765
# R^2 0.45890453217
# mean squared error 0.0554562288885

# %%
linear_model(df_2012, 'vote_diff')
# Out:
# R^2 0.354068400502
# R^2 0.345896657584
# mean squared error 0.102611013234

# %% [markdown]
# # 2016

# %%
linear_model(df_2016, 'total_vote_ratio')
# Out:
# R^2 0.350819603944
# R^2 0.40874831691
# mean squared error 0.0610019367211

# %%
linear_model(df_2016, 'dem_vote_ratio')
# Out:
# R^2 0.383006746298
# R^2 0.388385115893
# mean squared error 0.0553044996053

# %%
linear_model(df_2016, 'rep_vote_ratio')
# Out:
# R^2 0.544180956798
# R^2 0.547916194689
# mean squared error 0.0564279764372

# %%
linear_model(df_2016, 'vote_diff')
# Out:
# R^2 0.514929477804
# R^2 0.506756710466
# mean squared error 0.0936171571831

# %% [markdown]
# <a id='section2'></a>
# # Gradient Boost

# %%
# possible targets ['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff']
def grad_model(df, target):
    X = df.drop(['total_vote_ratio', 'dem_vote_ratio', 'rep_vote_ratio', 'vote_diff'], axis=1)
    y = df[target]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

    ss = StandardScaler()
    X_train = ss.fit_transform(X_train)
    X_test = ss.transform(X_test)
    
    grad = GradientBoostingRegressor()
    grad.fit(X_train, y_train)
    
    print('R^2', grad.score(X_train, y_train))
    print('R^2', grad.score(X_test, y_test))
    
    predictions = grad.predict(X_test)
    
    print('mean squared error', np.sqrt(mean_squared_error(y_test, predictions)))
    
    if target == 'total_vote_ratio':
        color = 'rebeccapurple'
    elif target == 'dem_vote_ratio':
        color = 'cornflowerblue'
    elif target == 'rep_vote_ratio':
        color = 'firebrick'
    else:
        color = 'forestgreen'
    
    plt.scatter(y_test, predictions, alpha=.1, color=color)
    plt.title('Predictions versus Actual');
    plt.show()
    
    residuals = y_test.mean() - grad.predict(X_test)
    
    plt.scatter(y_test, residuals, alpha=.1, color=color)
    plt.title('Residuals');
    plt.show()
    
    plt.hist(residuals, bins=25, color=color)
    plt.title("Histogram of Residuals");
    
    
    feature_importance = pd.DataFrame()
    feature_importance['feature_name'] = X.columns
    feature_importance['coefficients'] = grad.feature_importances_ 

    
    fig, ax = plt.subplots()
    fig.set_size_inches(10, 10)

    feat = feature_importance['feature_name']
    y_pos = np.arange(len(feat))
    coeff = feature_importance['coefficients']

    ax.barh(y_pos, coeff, align='center', color=color)
    ax.set_yticks(y_pos)
    ax.set_yticklabels(feat)
    ax.invert_yaxis() 
    plt.title('Feature Importance')
    plt.show()

# %% [markdown]
# # 2004

# %%
grad_model(df_2004, 'total_vote_ratio')
# Out:
# R^2 0.717002823834
# R^2 0.592758148077
# mean squared error 0.0511808798747

# %%
grad_model(df_2004, 'dem_vote_ratio')
# Out:
# R^2 0.574100839671
# R^2 0.363904283877
# mean squared error 0.0516853741546

# %%
grad_model(df_2004, 'rep_vote_ratio')
# Out:
# R^2 0.733421376499
# R^2 0.628429763195
# mean squared error 0.0457306191748

# %%
grad_model(df_2004, 'vote_diff')
# Out:
# R^2 0.643576375346
# R^2 0.478982550062
# mean squared error 0.0830041847773

# %% [markdown]
# # 2008

# %%
grad_model(df_2008, 'total_vote_ratio')
# Out:
# R^2 0.671011662952
# R^2 0.565907500305
# mean squared error 0.0524131106163

# %%
grad_model(df_2008, 'dem_vote_ratio')
# Out:
# R^2 0.60750381798
# R^2 0.431371995987
# mean squared error 0.0560032245335

# %%
grad_model(df_2008, 'rep_vote_ratio')
# Out:
# R^2 0.695575942875
# R^2 0.554209276428
# mean squared error 0.0479869472686

# %%
grad_model(df_2008, 'vote_diff')
# Out:
# R^2 0.644556150025
# R^2 0.446290217486
# mean squared error 0.0912383761614

# %% [markdown]
# # 2012

# %%
grad_model(df_2012, 'total_vote_ratio')
# Out:
# R^2 0.636715752068
# R^2 0.538141906799
# mean squared error 0.0574710226315

# %%
grad_model(df_2012, 'dem_vote_ratio')
# Out:
# R^2 0.60490632775
# R^2 0.408305637387
# mean squared error 0.0589729486193

# %%
grad_model(df_2012, 'rep_vote_ratio')
# Out:
# R^2 0.683550789649
# R^2 0.586764639181
# mean squared error 0.0496815203752

# %%
grad_model(df_2012, 'vote_diff')
# Out:
# R^2 0.64525267723
# R^2 0.470692501971
# mean squared error 0.0935952090831

# %% [markdown]
# # 2016

# %%
grad_model(df_2016, 'total_vote_ratio')
# Out:
# R^2 0.610936932657
# R^2 0.497490900053
# mean squared error 0.0563922643382

# %%
grad_model(df_2016, 'dem_vote_ratio')
# Out:
# R^2 0.667712675398
# R^2 0.478826940235
# mean squared error 0.0515672399914

# %%
grad_model(df_2016, 'rep_vote_ratio')
# Out:
# R^2 0.75099241112
# R^2 0.641654216786
# mean squared error 0.0511828199363

# %%
grad_model(df_2016, 'vote_diff')
# Out:
# R^2 0.741834887593
# R^2 0.591531475545
# mean squared error 0.0869223900743

# %% [markdown]
# ### Next Notebook [Mini Time Series Modeling](Mini_Time_posing.ipynb)
