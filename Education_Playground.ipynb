# %% [markdown]
# # Education Playground

# %%
import pandas as pd
import numpy as np

# %%
edu = pd.read_csv('./raw_csv_files/education.csv')

# %%
pd.set_option("display.max_columns", 999)

# %% [markdown]
# Data Dict
#
# 2003 Rural-urban Continuum Code
# 2003 Urban Influence Code
# Less than a high school diploma, 1990
# High school diploma only, 1990
# Some college or associate's degree, 1990
# Bachelor's degree or higher, 1990
# Percent of adults with less than a high school diploma, 1990
# Percent of adults with a high school diploma only, 1990
# Percent of adults completing some college or associate's degree, 1990
# Percent of adults with a bachelor's degree or higher, 1990
# Less than a high school diploma, 2000
# High school diploma only, 2000
# Some college or associate's degree, 2000
# Bachelor's degree or higher, 2000
# Percent of adults with less than a high school diploma, 2000
# Percent of adults with a high school diploma only, 2000
# Percent of adults completing some college or associate's degree, 2000
# Percent of adults with a bachelor's degree or higher, 2000
# 2013 Rural-urban Continuum Code	2013 Urban Influence Code
# Less than a high school diploma, 2011-2015
# High school diploma only, 2011-2015
# Some college or associate's degree, 2011-2015
# Bachelor's degree or higher, 2011-2015
# Percent of adults with less than a high school diploma, 2011-2015
# Percent of adults with a high school diploma only, 2011-2015
# Percent of adults completing some college or associate's degree, 2011-2015
# Percent of adults with a bachelor's degree or higher, 2011-2015

# %% [markdown]
# 2003 Rural-urban Continuum Code
#     The 2013 Rural-Urban Continuum Codes form a classification scheme that distinguishes metropolitan counties by the population size of their metro area, and nonmetropolitan counties by degree of urbanization and adjacency to a metro area. https://www.ers.usda.gov/data-products/rural-urban-continuum-codes/
#     1 - 9 classifications
#
#     - 1 Metro - Counties in metro areas of 1 million population or more
#     - 2 Metro - Counties in metro areas of 250,000 to 1 million population
#     - 3 Metro - Counties in metro areas of fewer than 250,000 population
#     - 4 Nonmetro - Urban population of 20,000 or more, adjacent to a metro area
#     - 5 Nonmetro - Urban population of 20,000 or more, not adjacent to a metro area
#     - 6 Nonmetro - Urban population of 2,500 to 19,999, adjacent to a metro area
#     - 7 Nonmetro - Urban population of 2,500 to 19,999, not adjacent to a metro area
#     - 8 Nonmetro - Completely rural or less than 2,500 urban population, adjacent to a metro area
#     - 9 Nonmetro - Completely rural or less than 2,500 urban population, not adjacent to a metro area
#
#
#
# 2003 Urban Influence Code
#     The 2013 Urban Influence Codes form a classification scheme that distinguishes metropolitan counties by population size of their metro area, and nonmetropolitan counties by size of the largest city or town and proximity to metro and micropolitan areas. - https://www.ers.usda.gov/data-products/urban-influence-codes/
#     1-12 classifications
#     - 1 Large-in a metro area with at least 1 million residents or more
#     - 2 Small-in a metro area with fewer than 1 million residents
#     - 3 Micropolitan adjacent to a large metro area
#     - 4 Noncore adjacent to a large metro area
#     - 5 Micropolitan adjacent to a small metro area
#     - 6 Noncore adjacent to a small metro with town of at least 2,500 residents
#     - 7 Noncore adjacent to a small metro and does not contain a town of at least 2,500 residents
#     - 8 Micropolitan not adjacent to a metro area
#     - 9 Noncore adjacent to micro area and contains a town of 2,500-19,999 residents
#     - 10 Noncore adjacent to micro area and does not contain a town of at least 2,500 residents
#     - 11 Noncore not adjacent to a metro/micro area and contains a town of 2,500  or more residents
#     - 12 Noncore not adjacent to a metro/micro area and does not contain a town of at least 2,500 residents

# %%
edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3111 entries, 0 to 3110
# Data columns (total 30 columns):
# state                           3111 non-null object
# county                          3111 non-null object
# 2003 Continuum                  3111 non-null int64
# 2003 Influence                  3111 non-null int64
# Less high 1990                  3110 non-null float64
# High diploma 1990               3110 non-null float64
# Some college 1990               3110 non-null float64
# Bachelors or higher 1990        3110 non-null float64
# Per less high 1990              3110 non-null float64
# Per high diploma 1990           3110 non-null float64
# Per some college 1990           3110 non-null float64
# Per bachelors or higher 1990    3110 non-null float64
# Less high 2000                  3110 non-null float64
# High diploma 2000               3110 non-null float64
# Some college 2000               3110 non-null float64
# Bachelors or higher 2000        3110 non-null float64
# Per less high 2000              3110 non-null float64
# Per high diploma 2000           3110 non-null float64
# Per some college 2000           3110 non-null float64
# Per bachelors or higher 2000    3110 non-null float64
# 2013 Continuum                  3111 non-null int64
# 2013 Urban Influence Code       3111 non-null int64
# Less high 2011                  3111 non-null int64
# High diploma 2011               3111 non-null int64
# Some college 2011               3111 non-null int64
# Bachelors or higher 2011        3111 non-null int64
# Per less high 2011              3111 non-null float64
# Per high diploma 2011           3111 non-null float64
# Per some college 2011           3111 non-null float64
# Per bachelors or higher 2011    3111 non-null float64
# dtypes: float64(20), int64(8), object(2)
# memory usage: 729.2+ KB

# %%
edu.head()
# Out:
#      state          county  2003 Continuum  2003 Influence  Less high 1990  \
# 0  Alabama  Autauga County               2               2          6252.0
# 1  Alabama  Baldwin County               4               5         17309.0
# 2  Alabama  Barbour County               6               6          6965.0
# 3  Alabama     Bibb County               1               1          4850.0
# 4  Alabama   Blount County               1               1          9960.0
#
#    High diploma 1990  Some college 1990  Bachelors or higher 1990  \
# 0             6671.0             4912.0                    3026.0
# 1            20544.0            15900.0                   10870.0
# 2             4258.0             2622.0                    1857.0
# 3             3407.0             1332.0                     476.0
# 4             8763.0             4745.0                    1773.0
#
#    Per less high 1990  Per high diploma 1990  Per some college 1990  \
# 0                30.0                   32.0                   23.5
# 1                26.8                   31.8                   24.6
# 2                44.4                   27.1                   16.7
# 3                48.2                   33.8                   13.2
# 4                39.5                   34.7                   18.8
#
#    Per bachelors or higher 1990  Less high 2000  High diploma 2000  \
# 0                          14.5          5872.0             9332.0
# 1                          16.8         17258.0            28428.0
# 2                          11.8          6679.0             6124.0
# 3                           4.7          4984.0             4838.0
# 4                           7.0          9960.0            12136.0
#
#    Some college 2000  Bachelors or higher 2000  Per less high 2000  \
# 0             7413.0                    4972.0                21.3
# 1            28178.0                   22146.0                18.0
# 2             4025.0                    2068.0                35.3
# 3             2756.0                     962.0                36.8
# 4             8371.0                    3235.0                29.6
#
#    Per high diploma 2000  Per some college 2000  Per bachelors or higher 2000  \
# 0                   33.8                   26.9                          18.0
# 1                   29.6                   29.3                          23.1
# 2                   32.4                   21.3                          10.9
# 3                   35.7                   20.4                           7.1
# 4                   36.0                   24.8                           9.6
#
#    2013 Continuum  2013 Urban Influence Code  Less high 2011  \
# 0               2                          2            4656
# 1               3                          2           14360
# 2               6                          6            5021
# 3               1                          1            3024
# 4               1                          1            8472
#
#    High diploma 2011  Some college 2011  Bachelors or higher 2011  \
# 0              12182              11044                      8437
# 1              39431              43500                     39710
# 2               6490               4943                      2354
# 3               6574               4367                      1664
# 4              13179              12677                      5080
#
#    Per less high 2011  Per high diploma 2011  Per some college 2011  \
# 0                12.8                   33.5                   30.4
# 1                10.5                   28.8                   31.8
# 2                26.7                   34.5                   26.3
# 3                19.3                   42.1                   27.9
# 4                21.5                   33.4                   32.2
#
#    Per bachelors or higher 2011
# 0                          23.2
# 1                          29.0
# 2                          12.5
# 3                          10.6
# 4                          12.9

# %%
edu.county = edu.county.map(lambda x: str(x)[:-7] if str(x)[-3] == 'n' or str(x)[-1] == 'h' else str(x)[:-5] + ' Co.')

# %%
edu.shape
# Out:
# (3111, 30)

# %% [markdown]
# Deal with null values

# %%
edu.isnull().sum().sum()
# Out:
# 16

# %%
edu.tail(100)
# Out:
#               state       county  2003 Continuum  2003 Influence  \
# 3011  West Virginia      Webster               9              12
# 3012  West Virginia       Wetzel               6               6
# 3013  West Virginia         Wirt               3               2
# 3014  West Virginia         Wood               3               2
# 3015  West Virginia      Wyoming               7              10
# 3016      Wisconsin        Adams               8               7
# 3017      Wisconsin      Ashland               7              11
# 3018      Wisconsin       Barron               6               6
# 3019      Wisconsin     Bayfield               8               7
# 3020      Wisconsin        Brown               2               2
# 3021      Wisconsin      Buffalo               8               6
# 3022      Wisconsin      Burnett               8               4
# 3023      Wisconsin      Calumet               3               2
# 3024      Wisconsin     Chippewa               3               2
# 3025      Wisconsin        Clark               8               6
# 3026      Wisconsin     Columbia               2               2
# 3027      Wisconsin     Crawford               7               9
# 3028      Wisconsin         Dane               2               2
# 3029      Wisconsin        Dodge               4               3
# 3030      Wisconsin         Door               6               6
# 3031      Wisconsin      Douglas               2               2
# 3032      Wisconsin         Dunn               6               5
# 3033      Wisconsin   Eau Claire               3               2
# 3034      Wisconsin     Florence               9               8
# 3035      Wisconsin  Fond du Lac               3               2
# 3036      Wisconsin       Forest               9              10
# 3037      Wisconsin        Grant               6               5
# 3038      Wisconsin        Green               6               5
# 3039      Wisconsin   Green Lake               6               6
# 3040      Wisconsin         Iowa               2               2
# ...             ...          ...             ...             ...
# 3081      Wisconsin     Washburn               6               6
# 3082      Wisconsin   Washington               1               1
# 3083      Wisconsin     Waukesha               1               1
# 3084      Wisconsin      Waupaca               6               6
# 3085      Wisconsin     Waushara               8               6
# 3086      Wisconsin    Winnebago               3               2
# 3087      Wisconsin         Wood               4               5
# 3088        Wyoming       Albany               4               5
# 3089        Wyoming     Big Horn               9              12
# 3090        Wyoming     Campbell               5               8
# 3091        Wyoming       Carbon               7               9
# 3092        Wyoming     Converse               6               6
# 3093        Wyoming        Crook               9              10
# 3094        Wyoming      Fremont               7               8
# 3095        Wyoming       Goshen               7               9
# 3096        Wyoming  Hot Springs               7               9
# 3097        Wyoming      Johnson               7               9
# 3098        Wyoming      Laramie               3               2
# 3099        Wyoming      Lincoln               7               9
# 3100        Wyoming      Natrona               3               2
# 3101        Wyoming     Niobrara               9              12
# 3102        Wyoming         Park               7              11
# 3103        Wyoming       Platte               7              11
# 3104        Wyoming     Sheridan               7               8
# 3105        Wyoming     Sublette               9              10
# 3106        Wyoming   Sweetwater               5               8
# 3107        Wyoming        Teton               7               8
# 3108        Wyoming        Uinta               7               8
# 3109        Wyoming     Washakie               7              11
# 3110        Wyoming       Weston               7               9
#
#       Less high 1990  High diploma 1990  Some college 1990  \
# 3011          3687.0             2128.0              696.0
# 3012          3745.0             5512.0             1985.0
# 3013          1145.0             1446.0              522.0
# 3014         15532.0            21088.0            13564.0
# 3015          8499.0             6421.0             2044.0
# 3016          3757.0             4534.0             2245.0
# 3017          2534.0             4049.0             2367.0
# 3018          7080.0            10161.0             5879.0
# 3019          2021.0             3392.0             2286.0
# 3020         20927.0            48840.0            29488.0
# 3021          2443.0             3745.0             1764.0
# 3022          2507.0             4049.0             1682.0
# 3023          4260.0             9772.0             4208.0
# 3024          8323.0            14639.0             6656.0
# 3025          6396.0             8518.0             3086.0
# 3026          6445.0            12133.0             7236.0
# 3027          2807.0             4445.0             1816.0
# 3028         25086.0            61115.0            62596.0
# 3029         13776.0            21602.0             9238.0
# 3030          3549.0             7021.0             3945.0
# 3031          6165.0            10705.0             6173.0
# 3032          4413.0             7356.0             4144.0
# 3033          8491.0            17509.0            13002.0
# 3034           759.0             1345.0              680.0
# 3035         12768.0            24259.0            12174.0
# 3036          2012.0             2177.0              990.0
# 3037          6450.0            12464.0             5956.0
# 3038          4577.0             8532.0             4235.0
# 3039          3169.0             5364.0             2500.0
# 3040          2473.0             5812.0             2770.0
# ...              ...                ...                ...
# 3081          2338.0             3767.0             2006.0
# 3082         11118.0            23813.0            15174.0
# 3083         23522.0            63044.0            56285.0
# 3084          8389.0            13149.0             5265.0
# 3085          3994.0             5539.0             2457.0
# 3086         17241.0            35255.0            20302.0
# 3087         10157.0            19986.0            10338.0
# 3088          1742.0             3413.0             4863.0
# 3089          1534.0             2424.0             1726.0
# 3090          2262.0             6336.0             5512.0
# 3091          1913.0             4033.0             3041.0
# 3092          1122.0             2673.0             2091.0
# 3093           674.0             1191.0              934.0
# 3094          4646.0             6973.0             5614.0
# 3095          1854.0             2619.0             2267.0
# 3096           790.0             1182.0              858.0
# 3097           833.0             1435.0             1119.0
# 3098          7241.0            13283.0            15763.0
# 3099          1183.0             2742.0             2058.0
# 3100          5668.0            11922.0            13020.0
# 3101           427.0              598.0              506.0
# 3102          2557.0             4587.0             4798.0
# 3103          1081.0             2110.0             1526.0
# 3104          2870.0             5260.0             4743.0
# 3105           504.0             1063.0              939.0
# 3106          4160.0             8455.0             6912.0
# 3107           620.0             2177.0             2549.0
# 3108          1581.0             3897.0             3028.0
# 3109          1150.0             1876.0             1406.0
# 3110           701.0             1832.0             1107.0
#
#       Bachelors or higher 1990  Per less high 1990  Per high diploma 1990  \
# 3011                     383.0                53.5                   30.9
# 3012                    1303.0                29.9                   43.9
# 3013                     270.0                33.8                   42.7
# 3014                    7804.0                26.8                   36.4
# 3015                    1114.0                47.0                   35.5
# 3016                     842.0                33.0                   39.8
# 3017                    1312.0                24.7                   39.5
# 3018                    3078.0                27.0                   38.8
# 3019                    1719.0                21.5                   36.0
# 3020                   21320.0                17.4                   40.5
# 3021                     966.0                27.4                   42.0
# 3022                     807.0                27.7                   44.8
# 3023                    2700.0                20.3                   46.7
# 3024                    3577.0                25.1                   44.1
# 3025                    1702.0                32.5                   43.2
# 3026                    3823.0                21.7                   40.9
# 3027                    1101.0                27.6                   43.7
# 3028                   77176.0                11.1                   27.0
# 3029                    5078.0                27.7                   43.5
# 3030                    2854.0                20.4                   40.4
# 3031                    4017.0                22.8                   39.6
# 3032                    3842.0                22.3                   37.2
# 3033                   10334.0                17.2                   35.5
# 3034                     273.0                24.8                   44.0
# 3035                    7563.0                22.5                   42.7
# 3036                     429.0                35.9                   38.8
# 3037                    4290.0                22.1                   42.7
# 3038                    2364.0                23.2                   43.3
# 3039                    1420.0                25.4                   43.1
# 3040                    1692.0                19.4                   45.6
# ...                        ...                 ...                    ...
# 3081                    1186.0                25.1                   40.5
# 3082                    9478.0                18.7                   40.0
# 3083                   52986.0                12.0                   32.2
# 3084                    3306.0                27.9                   43.7
# 3085                    1326.0                30.0                   41.6
# 3086                   16162.0                19.4                   39.6
# 3087                    6315.0                21.7                   42.7
# 3088                    6279.0                10.7                   20.9
# 3089                    1003.0                22.9                   36.2
# 3090                    2630.0                13.5                   37.8
# 3091                    1484.0                18.3                   38.5
# 3092                     860.0                16.6                   39.6
# 3093                     518.0                20.3                   35.9
# 3094                    3412.0                22.5                   33.8
# 3095                    1145.0                23.5                   33.2
# 3096                     472.0                23.9                   35.8
# 3097                     740.0                20.2                   34.8
# 3098                    9467.0                15.8                   29.0
# 3099                    1075.0                16.8                   38.8
# 3100                    7823.0                14.7                   31.0
# 3101                     229.0                24.3                   34.0
# 3102                    2763.0                17.4                   31.2
# 3103                     604.0                20.3                   39.7
# 3104                    2757.0                18.4                   33.7
# 3105                     681.0                15.8                   33.4
# 3106                    3006.0                18.5                   37.5
# 3107                    2291.0                 8.1                   28.5
# 3108                    1425.0                15.9                   39.2
# 3109                    1000.0                21.2                   34.5
# 3110                     531.0                16.8                   43.9
#
#       Per some college 1990  Per bachelors or higher 1990  Less high 2000  \
# 3011                   10.1                           5.6          2801.0
# 3012                   15.8                          10.4          2755.0
# 3013                   15.4                           8.0          1089.0
# 3014                   23.4                          13.5         11299.0
# 3015                   11.3                           6.2          6326.0
# 3016                   19.7                           7.4          3202.0
# 3017                   23.1                          12.8          1697.0
# 3018                   22.4                          11.7          5281.0
# 3019                   24.3                          18.3          1374.0
# 3020                   24.5                          17.7         19743.0
# 3021                   19.8                          10.8          1488.0
# 3022                   18.6                           8.9          1944.0
# 3023                   20.1                          12.9          3304.0
# 3024                   20.1                          10.8          5718.0
# 3025                   15.7                           8.6          5169.0
# 3026                   24.4                          12.9          4904.0
# 3027                   17.9                          10.8          2115.0
# 3028                   27.7                          34.2         21177.0
# 3029                   18.6                          10.2         10153.0
# 3030                   22.7                          16.4          2453.0
# 3031                   22.8                          14.8          4053.0
# 3032                   21.0                          19.4          3023.0
# 3033                   26.4                          20.9          6133.0
# 3034                   22.2                           8.9           592.0
# 3035                   21.4                          13.3         10026.0
# 3036                   17.7                           7.6          1439.0
# 3037                   20.4                          14.7          5059.0
# 3038                   21.5                          12.0          3577.0
# 3039                   20.1                          11.4          2394.0
# 3040                   21.7                          13.3          1743.0
# ...                     ...                           ...             ...
# 3081                   21.6                          12.8          1828.0
# 3082                   25.5                          15.9          8738.0
# 3083                   28.7                          27.1         19410.0
# 3084                   17.5                          11.0          6022.0
# 3085                   18.5                          10.0          3457.0
# 3086                   22.8                          18.2         13867.0
# 3087                   22.1                          13.5          7662.0
# 3088                   29.8                          38.5          1114.0
# 3089                   25.8                          15.0          1235.0
# 3090                   32.9                          15.7          2343.0
# 3091                   29.0                          14.2          1733.0
# 3092                   31.0                          12.7          1063.0
# 3093                   28.2                          15.6           553.0
# 3094                   27.2                          16.5          3499.0
# 3095                   28.8                          14.5          1283.0
# 3096                   26.0                          14.3           556.0
# 3097                   27.1                          17.9           492.0
# 3098                   34.5                          20.7          5766.0
# 3099                   29.2                          15.2          1093.0
# 3100                   33.9                          20.4          5006.0
# 3101                   28.7                          13.0           220.0
# 3102                   32.6                          18.8          2124.0
# 3103                   28.7                          11.4           913.0
# 3104                   30.3                          17.6          2085.0
# 3105                   29.5                          21.4           446.0
# 3106                   30.7                          13.3          2911.0
# 3107                   33.4                          30.0           679.0
# 3108                   30.5                          14.3          1744.0
# 3109                   25.9                          18.4           785.0
# 3110                   26.5                          12.7           674.0
#
#       High diploma 2000  Some college 2000  Bachelors or higher 2000  \
# 3011             2439.0              876.0                     585.0
# 3012             5839.0             2415.0                    1278.0
# 3013             1775.0              691.0                     389.0
# 3014            23225.0            16923.0                    9250.0
# 3015             7413.0             2716.0                    1267.0
# 3016             5755.0             3404.0                    1369.0
# 3017             4322.0             2888.0                    1761.0
# 3018            11816.0             8392.0                    4453.0
# 3019             3598.0             3283.0                    2271.0
# 3020            50311.0            41729.0                   32389.0
# 3021             4110.0             2468.0                    1318.0
# 3022             4811.0             2941.0                    1577.0
# 3023            10575.0             6774.0                    5415.0
# 3024            14885.0            10399.0                    5328.0
# 3025             8951.0             4704.0                    2167.0
# 3026            14108.0            10576.0                    5941.0
# 3027             4802.0             2895.0                    1489.0
# 3028            60220.0            78878.0                  109723.0
# 3029            25031.0            14667.0                    7602.0
# 3030             7741.0             5574.0                    4294.0
# 3031            10370.0             8990.0                    5240.0
# 3032             8353.0             6496.0                    4772.0
# 3033            17212.0            17009.0                   14936.0
# 3034             1614.0              982.0                     453.0
# 3035            25479.0            17328.0                   10715.0
# 3036             2859.0             1725.0                     671.0
# 3037            12255.0             8058.0                    5253.0
# 3038             9085.0             6107.0                    3754.0
# 3039             5547.0             3372.0                    1916.0
# 3040             6306.0             4264.0                    2787.0
# ...                 ...                ...                       ...
# 3081             4464.0             3241.0                    1715.0
# 3082            27308.0            24606.0                   17057.0
# 3083            66651.0            72975.0                   82263.0
# 3084            15148.0             8400.0                    5156.0
# 3085             7034.0             3908.0                    1911.0
# 3086            37849.0            26351.0                   23028.0
# 3087            20618.0            13493.0                    8486.0
# 3088             3727.0             4676.0                    7499.0
# 3089             2506.0             2432.0                    1170.0
# 3090             7106.0             7508.0                    3150.0
# 3091             3678.0             3294.0                    1803.0
# 3092             2766.0             2837.0                    1152.0
# 3093             1479.0             1177.0                     679.0
# 3094             7658.0             7359.0                    4537.0
# 3095             2810.0             2747.0                    1566.0
# 3096             1270.0             1059.0                     630.0
# 3097             1539.0             1843.0                    1107.0
# 3098            14053.0            20784.0                   12438.0
# 3099             3151.0             3250.0                    1555.0
# 3100            13057.0            16055.0                    8538.0
# 3101              673.0              573.0                     265.0
# 3102             5208.0             5756.0                    4057.0
# 3103             2323.0             1880.0                     918.0
# 3104             5180.0             6689.0                    4026.0
# 3105             1429.0             1297.0                     872.0
# 3106             7994.0             8220.0                    3928.0
# 3107             2428.0             3853.0                    5878.0
# 3108             4069.0             3918.0                    1712.0
# 3109             1844.0             1809.0                    1022.0
# 3110             1831.0             1389.0                     660.0
#
#       Per less high 2000  Per high diploma 2000  Per some college 2000  \
# 3011                41.8                   36.4                   13.1
# 3012                22.4                   47.5                   19.7
# 3013                27.6                   45.0                   17.5
# 3014                18.6                   38.3                   27.9
# 3015                35.7                   41.8                   15.3
# 3016                23.3                   41.9                   24.8
# 3017                15.9                   40.5                   27.1
# 3018                17.6                   39.5                   28.0
# 3019                13.1                   34.2                   31.2
# 3020                13.7                   34.9                   28.9
# 3021                15.9                   43.8                   26.3
# 3022                17.2                   42.7                   26.1
# 3023                12.7                   40.6                   26.0
# 3024                15.7                   41.0                   28.6
# 3025                24.6                   42.6                   22.4
# 3026                13.8                   39.7                   29.8
# 3027                18.7                   42.5                   25.6
# 3028                 7.8                   22.3                   29.2
# 3029                17.7                   43.6                   25.5
# 3030                12.2                   38.6                   27.8
# 3031                14.1                   36.2                   31.4
# 3032                13.4                   36.9                   28.7
# 3033                11.1                   31.1                   30.8
# 3034                16.3                   44.3                   27.0
# 3035                15.8                   40.1                   27.3
# 3036                21.5                   42.7                   25.8
# 3037                16.5                   40.0                   26.3
# 3038                15.9                   40.3                   27.1
# 3039                18.1                   41.9                   25.5
# 3040                11.5                   41.8                   28.2
# ...                  ...                    ...                    ...
# 3081                16.3                   39.7                   28.8
# 3082                11.2                   35.1                   31.7
# 3083                 8.0                   27.6                   30.2
# 3084                17.3                   43.6                   24.2
# 3085                21.2                   43.1                   24.0
# 3086                13.7                   37.4                   26.1
# 3087                15.2                   41.0                   26.8
# 3088                 6.5                   21.9                   27.5
# 3089                16.8                   34.1                   33.1
# 3090                11.7                   35.3                   37.3
# 3091                16.5                   35.0                   31.3
# 3092                13.6                   35.4                   36.3
# 3093                14.2                   38.0                   30.3
# 3094                15.2                   33.2                   31.9
# 3095                15.3                   33.4                   32.7
# 3096                15.8                   36.1                   30.1
# 3097                 9.9                   30.9                   37.0
# 3098                10.9                   26.5                   39.2
# 3099                12.1                   34.8                   35.9
# 3100                11.7                   30.6                   37.6
# 3101                12.7                   38.9                   33.1
# 3102                12.4                   30.4                   33.6
# 3103                15.1                   38.5                   31.2
# 3104                11.6                   28.8                   37.2
# 3105                11.0                   35.3                   32.1
# 3106                12.6                   34.7                   35.7
# 3107                 5.3                   18.9                   30.0
# 3108                15.2                   35.6                   34.2
# 3109                14.4                   33.8                   33.1
# 3110                14.8                   40.2                   30.5
#
#       Per bachelors or higher 2000  2013 Continuum  2013 Urban Influence Code  \
# 3011                           8.7               9                         12
# 3012                          10.4               6                          6
# 3013                           9.9               3                          2
# 3014                          15.2               3                          2
# 3015                           7.1               6                          7
# 3016                          10.0               8                          6
# 3017                          16.5               7                         11
# 3018                          14.9               6                          6
# 3019                          21.6               8                          6
# 3020                          22.5               2                          2
# 3021                          14.0               8                          6
# 3022                          14.0               8                          4
# 3023                          20.8               3                          2
# 3024                          14.7               3                          2
# 3025                          10.3               6                          6
# 3026                          16.7               2                          2
# 3027                          13.2               7                          9
# 3028                          40.6               2                          2
# 3029                          13.2               4                          3
# 3030                          21.4               6                          6
# 3031                          18.3               2                          2
# 3032                          21.1               6                          3
# 3033                          27.0               3                          2
# 3034                          12.4               9                          8
# 3035                          16.9               3                          2
# 3036                          10.0               9                         12
# 3037                          17.2               6                          5
# 3038                          16.7               2                          2
# 3039                          14.5               6                          6
# 3040                          18.5               2                          2
# ...                            ...             ...                        ...
# 3081                          15.2               7                         11
# 3082                          21.9               1                          1
# 3083                          34.1               1                          1
# 3084                          14.8               6                          6
# 3085                          11.7               6                          6
# 3086                          22.8               3                          2
# 3087                          16.9               4                          5
# 3088                          44.1               4                          5
# 3089                          15.9               9                         12
# 3090                          15.7               5                          8
# 3091                          17.2               7                          9
# 3092                          14.7               6                          6
# 3093                          17.5               9                         10
# 3094                          19.7               7                          8
# 3095                          18.6               7                          9
# 3096                          17.9               7                          9
# 3097                          22.2               7                          9
# 3098                          23.4               3                          2
# 3099                          17.2               7                          9
# 3100                          20.0               3                          2
# 3101                          15.3               9                         12
# 3102                          23.7               7                         11
# 3103                          15.2               7                         11
# 3104                          22.4               7                          8
# 3105                          21.6               9                         10
# 3106                          17.0               5                          8
# 3107                          45.8               7                          8
# 3108                          15.0               7                          8
# 3109                          18.7               7                         11
# 3110                          14.5               7                          9
#
#       Less high 2011  High diploma 2011  Some college 2011  \
# 3011            1888               2791               1215
# 3012            1877               5668               2887
# 3013             580               1966               1085
# 3014            6664              23359              19795
# 3015            4036               7469               3457
# 3016            2064               7061               4966
# 3017             828               3786               3687
# 3018            3405              12904              10725
# 3019             688               3462               3946
# 3020           15827              52583              52690
# 3021             830               4053               2934
# 3022            1006               4648               3918
# 3023            2360              11185              10171
# 3024            3629              16934              15004
# 3025            4044               9430               5781
# 3026            2973              13885              14109
# 3027            1193               5058               3809
# 3028           16694              63169              93413
# 3029            7427              25339              19900
# 3030            1367               7036               6636
# 3031            2021              10152              11496
# 3032            1947               9279               8752
# 3033            4275              16961              22176
# 3034             307               1365               1211
# 3035            6101              27080              22031
# 3036             852               2629               2093
# 3037            2726              12302               9981
# 3038            2008              10074               8073
# 3039            1613               5682               3863
# 3040            1137               6031               5631
# ...              ...                ...                ...
# 3081            1013               4543               3732
# 3082            6200              27755              31822
# 3083           11789              66675              82952
# 3084            3613              16245              11006
# 3085            2408               7670               5419
# 3086            9053              38255              35426
# 3087            4189              20458              17289
# 3088             699               3438               6120
# 3089             890               2490               3018
# 3090            2614              10385              11345
# 3091             981               3802               3820
# 3092             823               3606               3396
# 3093             356               1755               1999
# 3094            2240               8552              10461
# 3095             864               2833               3603
# 3096             321               1081               1388
# 3097             340               2183               1997
# 3098            4374              16667              24675
# 3099             798               3812               4889
# 3100            4685              14676              22398
# 3101             177                524                765
# 3102            1378               5807               7391
# 3103             491               1962               2531
# 3104            1145               5675               7921
# 3105             316               2454               2601
# 3106            2702              10093              10121
# 3107             687               3008               4055
# 3108            1343               4713               4456
# 3109             732               1704               2151
# 3110             610               1652               1933
#
#       Bachelors or higher 2011  Per less high 2011  Per high diploma 2011  \
# 3011                       603                29.1                   43.0
# 3012                      1212                16.1                   48.7
# 3013                       497                14.1                   47.6
# 3014                     11519                10.9                   38.1
# 3015                      1291                24.8                   46.0
# 3016                      2072                12.8                   43.7
# 3017                      2509                 7.7                   35.0
# 3018                      5383                10.5                   39.8
# 3019                      3351                 6.0                   30.2
# 3020                     46961                 9.4                   31.3
# 3021                      1714                 8.7                   42.5
# 3022                      2061                 8.6                   40.0
# 3023                      9407                 7.1                   33.8
# 3024                      8452                 8.2                   38.5
# 3025                      2508                18.6                   43.3
# 3026                      8766                 7.5                   34.9
# 3027                      1789                10.1                   42.7
# 3028                    159408                 5.0                   19.0
# 3029                     10365                11.8                   40.2
# 3030                      6354                 6.4                   32.9
# 3031                      6871                 6.6                   33.2
# 3032                      6874                 7.3                   34.6
# 3033                     19584                 6.8                   26.9
# 3034                       596                 8.8                   39.2
# 3035                     15140                 8.7                   38.5
# 3036                       889                13.2                   40.7
# 3037                      6774                 8.6                   38.7
# 3038                      5651                 7.8                   39.0
# 3039                      2267                12.0                   42.3
# 3040                      3798                 6.9                   36.3
# ...                        ...                 ...                    ...
# 3081                      2425                 8.6                   38.8
# 3082                     26685                 6.7                   30.0
# 3083                    113208                 4.3                   24.3
# 3084                      6295                 9.7                   43.7
# 3085                      2648                13.3                   42.3
# 3086                     29912                 8.0                   34.0
# 3087                     10214                 8.0                   39.2
# 3088                      9981                 3.5                   17.0
# 3089                      1555                11.2                   31.3
# 3090                      5834                 8.7                   34.4
# 3091                      2083                 9.2                   35.6
# 3092                      1664                 8.7                   38.0
# 3093                       953                 7.0                   34.7
# 3094                      5766                 8.3                   31.7
# 3095                      2162                 9.1                   29.9
# 3096                       725                 9.1                   30.8
# 3097                      1533                 5.6                   36.1
# 3098                     17637                 6.9                   26.3
# 3099                      2609                 6.6                   31.5
# 3100                     11684                 8.8                   27.5
# 3101                       396                 9.5                   28.1
# 3102                      5786                 6.8                   28.5
# 3103                      1379                 7.7                   30.8
# 3104                      6128                 5.5                   27.2
# 3105                      1594                 4.5                   35.2
# 3106                      5586                 9.5                   35.4
# 3107                      9073                 4.1                   17.9
# 3108                      2515                10.3                   36.2
# 3109                      1229                12.6                   29.3
# 3110                       928                11.9                   32.2
#
#       Per some college 2011  Per bachelors or higher 2011
# 3011                   18.7                           9.3
# 3012                   24.8                          10.4
# 3013                   26.3                          12.0
# 3014                   32.3                          18.8
# 3015                   21.3                           7.9
# 3016                   30.7                          12.8
# 3017                   34.1                          23.2
# 3018                   33.1                          16.6
# 3019                   34.5                          29.3
# 3020                   31.4                          27.9
# 3021                   30.8                          18.0
# 3022                   33.7                          17.7
# 3023                   30.7                          28.4
# 3024                   34.1                          19.2
# 3025                   26.6                          11.5
# 3026                   35.5                          22.1
# 3027                   32.1                          15.1
# 3028                   28.1                          47.9
# 3029                   31.6                          16.4
# 3030                   31.0                          29.7
# 3031                   37.6                          22.5
# 3032                   32.6                          25.6
# 3033                   35.2                          31.1
# 3034                   34.8                          17.1
# 3035                   31.3                          21.5
# 3036                   32.4                          13.8
# 3037                   31.4                          21.3
# 3038                   31.3                          21.9
# 3039                   28.8                          16.9
# 3040                   33.9                          22.9
# ...                     ...                           ...
# 3081                   31.9                          20.7
# 3082                   34.4                          28.9
# 3083                   30.2                          41.2
# 3084                   29.6                          16.9
# 3085                   29.9                          14.6
# 3086                   31.4                          26.6
# 3087                   33.2                          19.6
# 3088                   30.2                          49.3
# 3089                   37.9                          19.6
# 3090                   37.6                          19.3
# 3091                   35.7                          19.5
# 3092                   35.8                          17.5
# 3093                   39.5                          18.8
# 3094                   38.7                          21.3
# 3095                   38.1                          22.8
# 3096                   39.5                          20.6
# 3097                   33.0                          25.3
# 3098                   38.9                          27.8
# 3099                   40.4                          21.5
# 3100                   41.9                          21.9
# 3101                   41.1                          21.3
# 3102                   36.3                          28.4
# 3103                   39.8                          21.7
# 3104                   38.0                          29.4
# 3105                   37.3                          22.9
# 3106                   35.5                          19.6
# 3107                   24.1                          53.9
# 3108                   34.2                          19.3
# 3109                   37.0                          21.1
# 3110                   37.7                          18.1
#
# [100 rows x 30 columns]

# %%
edu = edu[:3111]

# %%
edu.shape
# Out:
# (3111, 30)

# %%
edu[edu.isnull().any(axis=1)]
# Out:
#         state      county  2003 Continuum  2003 Influence  Less high 1990  \
# 222  Colorado  Broomfield               1               1             NaN
#
#      High diploma 1990  Some college 1990  Bachelors or higher 1990  \
# 222                NaN                NaN                       NaN
#
#      Per less high 1990  Per high diploma 1990  Per some college 1990  \
# 222                 NaN                    NaN                    NaN
#
#      Per bachelors or higher 1990  Less high 2000  High diploma 2000  \
# 222                           NaN             NaN                NaN
#
#      Some college 2000  Bachelors or higher 2000  Per less high 2000  \
# 222                NaN                       NaN                 NaN
#
#      Per high diploma 2000  Per some college 2000  \
# 222                    NaN                    NaN
#
#      Per bachelors or higher 2000  2013 Continuum  2013 Urban Influence Code  \
# 222                           NaN               1                          1
#
#      Less high 2011  High diploma 2011  Some college 2011  \
# 222            1773               6010              11893
#
#      Bachelors or higher 2011  Per less high 2011  Per high diploma 2011  \
# 222                     21204                 4.3                   14.7
#
#      Per some college 2011  Per bachelors or higher 2011
# 222                   29.1                          51.9

# %%
edu.fillna(0, inplace=True)

# %%
def replace(df):
    '''Function to replace every state name in dataset with it's abbreviation'''
    
    df.state = df.state.replace('Alabama', 'AL').replace('Arizona', 'AZ').replace('Arkansas', 'AR')
    df.state = df.state.replace('California', 'CA').replace('Colorado', 'CO').replace('Connecticut', 'CT')
    df.state = df.state.replace('Delaware', 'DE').replace('Florida', 'FL').replace('Georgia', 'GA')
    df.state = df.state.replace('Hawaii', 'HI').replace('Idaho', 'ID').replace('Illinois', 'IL')
    df.state = df.state.replace('Indiana', 'IN').replace('Iowa', 'IA').replace('Kansas', 'KS')
    df.state = df.state.replace('Kentucky', 'KY').replace('Louisiana', 'LA').replace('Maine', 'ME')
    df.state = df.state.replace('Maryland', 'MD').replace('Massachusetts', 'MA').replace('Michigan', 'MI')
    df.state = df.state.replace('Minnesota', 'MN').replace('Mississippi', 'MS').replace('Missouri', 'MO')
    df.state = df.state.replace('Montana', 'MT').replace('Nebraska', 'NE').replace('Nevada', 'NV')
    df.state = df.state.replace('New Hampshire','NH').replace('New Jersey', 'NJ').replace('New Mexico', 'NM')
    df.state = df.state.replace('New York', 'NY').replace('North Carolina','NC').replace('North Dakota', 'ND')
    df.state = df.state.replace('Ohio', 'OH').replace('Oklahoma', 'OK').replace('Oregon', 'OR')
    df.state = df.state.replace('Pennsylvania', 'PA').replace('Rhode Island', 'RI').replace('South Carolina', 'SC')
    df.state = df.state.replace('South Dakota', 'SD').replace('Tennessee', 'TN').replace('Texas', 'TX')
    df.state = df.state.replace('Utah', 'UT').replace('Vermont', 'VT').replace('Virginia', 'VA')
    df.state = df.state.replace('Washington', 'WA').replace('West Virginia', 'WV').replace('Wisconsin', 'WI')
    df.state = df.state.replace('Wyoming', 'WY')
    return df

# %%
edu = replace(edu)

edu.county = edu.county + ', ' + edu.state

edu.drop('state', axis=1, inplace=True)

# %%
edu.head()
# Out:
#         county  2003 Continuum  2003 Influence  Less high 1990  \
# 0  Autauga, AL               2               2          6252.0
# 1  Baldwin, AL               4               5         17309.0
# 2  Barbour, AL               6               6          6965.0
# 3     Bibb, AL               1               1          4850.0
# 4   Blount, AL               1               1          9960.0
#
#    High diploma 1990  Some college 1990  Bachelors or higher 1990  \
# 0             6671.0             4912.0                    3026.0
# 1            20544.0            15900.0                   10870.0
# 2             4258.0             2622.0                    1857.0
# 3             3407.0             1332.0                     476.0
# 4             8763.0             4745.0                    1773.0
#
#    Per less high 1990  Per high diploma 1990  Per some college 1990  \
# 0                30.0                   32.0                   23.5
# 1                26.8                   31.8                   24.6
# 2                44.4                   27.1                   16.7
# 3                48.2                   33.8                   13.2
# 4                39.5                   34.7                   18.8
#
#    Per bachelors or higher 1990  Less high 2000  High diploma 2000  \
# 0                          14.5          5872.0             9332.0
# 1                          16.8         17258.0            28428.0
# 2                          11.8          6679.0             6124.0
# 3                           4.7          4984.0             4838.0
# 4                           7.0          9960.0            12136.0
#
#    Some college 2000  Bachelors or higher 2000  Per less high 2000  \
# 0             7413.0                    4972.0                21.3
# 1            28178.0                   22146.0                18.0
# 2             4025.0                    2068.0                35.3
# 3             2756.0                     962.0                36.8
# 4             8371.0                    3235.0                29.6
#
#    Per high diploma 2000  Per some college 2000  Per bachelors or higher 2000  \
# 0                   33.8                   26.9                          18.0
# 1                   29.6                   29.3                          23.1
# 2                   32.4                   21.3                          10.9
# 3                   35.7                   20.4                           7.1
# 4                   36.0                   24.8                           9.6
#
#    2013 Continuum  2013 Urban Influence Code  Less high 2011  \
# 0               2                          2            4656
# 1               3                          2           14360
# 2               6                          6            5021
# 3               1                          1            3024
# 4               1                          1            8472
#
#    High diploma 2011  Some college 2011  Bachelors or higher 2011  \
# 0              12182              11044                      8437
# 1              39431              43500                     39710
# 2               6490               4943                      2354
# 3               6574               4367                      1664
# 4              13179              12677                      5080
#
#    Per less high 2011  Per high diploma 2011  Per some college 2011  \
# 0                12.8                   33.5                   30.4
# 1                10.5                   28.8                   31.8
# 2                26.7                   34.5                   26.3
# 3                19.3                   42.1                   27.9
# 4                21.5                   33.4                   32.2
#
#    Per bachelors or higher 2011
# 0                          23.2
# 1                          29.0
# 2                          12.5
# 3                          10.6
# 4                          12.9

# %%
edu_2000 = edu[['county', '2003 Continuum', '2003 Influence', 'Less high 1990', 'High diploma 1990', 
               'Some college 1990', 'Bachelors or higher 1990', 'Per less high 1990', 'Per high diploma 1990', 
               'Per some college 1990', 'Per bachelors or higher 1990', 'Less high 2000', 
                'High diploma 2000', 'Some college 2000', 'Bachelors or higher 2000', 'Per less high 2000',
                'Per high diploma 2000', 'Per some college 2000', 'Per bachelors or higher 2000']]
edu_2010 = edu[['county', '2013 Continuum', '2013 Urban Influence Code', 'Less high 2000', 'High diploma 2000', 
                'Some college 2000', 'Bachelors or higher 2000', 'Per less high 2000', 'Per high diploma 2000', 
                'Per some college 2000', 'Per bachelors or higher 2000', 'Less high 2011',
                'High diploma 2011', 'Some college 2011', 'Bachelors or higher 2011', 'Per less high 2011',
                'Per high diploma 2011', 'Per some college 2011', 'Per bachelors or higher 2011']]

# %%
edu_2000
# Out:
#                county  2003 Continuum  2003 Influence  Less high 1990  \
# 0         Autauga, AL               2               2          6252.0
# 1         Baldwin, AL               4               5         17309.0
# 2         Barbour, AL               6               6          6965.0
# 3            Bibb, AL               1               1          4850.0
# 4          Blount, AL               1               1          9960.0
# 5         Bullock, AL               6               6          3428.0
# 6          Butler, AL               6               6          6374.0
# 7         Calhoun, AL               3               2         23633.0
# 8        Chambers, AL               6               5         10833.0
# 9        Cherokee, AL               8               6          6030.0
# 10        Chilton, AL               1               1          9023.0
# 11        Choctaw, AL               9              10          4482.0
# 12         Clarke, AL               7              11          6471.0
# 13           Clay, AL               9              10          3999.0
# 14       Cleburne, AL               8               4          4068.0
# 15         Coffee, AL               6               5          8522.0
# 16        Colbert, AL               3               2         11952.0
# 17        Conecuh, AL               9              11          4242.0
# 18          Coosa, AL               8               7          3315.0
# 19      Covington, AL               7               9         10288.0
# 20       Crenshaw, AL               8               6          4286.0
# 21        Cullman, AL               6               3         18093.0
# 22           Dale, AL               4               5          7536.0
# 23         Dallas, AL               4               5         11488.0
# 24         Dekalb, AL               6               6         16665.0
# 25         Elmore, AL               2               2         10518.0
# 26       Escambia, AL               6               6          9037.0
# 27         Etowah, AL               3               2         23588.0
# 28        Fayette, AL               6               6          5060.0
# 29       Franklin, AL               6               6          8212.0
# ...               ...             ...             ...             ...
# 3081     Washburn, WI               6               6          2338.0
# 3082   Washington, WI               1               1         11118.0
# 3083     Waukesha, WI               1               1         23522.0
# 3084      Waupaca, WI               6               6          8389.0
# 3085     Waushara, WI               8               6          3994.0
# 3086    Winnebago, WI               3               2         17241.0
# 3087         Wood, WI               4               5         10157.0
# 3088       Albany, WY               4               5          1742.0
# 3089     Big Horn, WY               9              12          1534.0
# 3090     Campbell, WY               5               8          2262.0
# 3091       Carbon, WY               7               9          1913.0
# 3092     Converse, WY               6               6          1122.0
# 3093        Crook, WY               9              10           674.0
# 3094      Fremont, WY               7               8          4646.0
# 3095       Goshen, WY               7               9          1854.0
# 3096  Hot Springs, WY               7               9           790.0
# 3097      Johnson, WY               7               9           833.0
# 3098      Laramie, WY               3               2          7241.0
# 3099      Lincoln, WY               7               9          1183.0
# 3100      Natrona, WY               3               2          5668.0
# 3101     Niobrara, WY               9              12           427.0
# 3102         Park, WY               7              11          2557.0
# 3103       Platte, WY               7              11          1081.0
# 3104     Sheridan, WY               7               8          2870.0
# 3105     Sublette, WY               9              10           504.0
# 3106   Sweetwater, WY               5               8          4160.0
# 3107        Teton, WY               7               8           620.0
# 3108        Uinta, WY               7               8          1581.0
# 3109     Washakie, WY               7              11          1150.0
# 3110       Weston, WY               7               9           701.0
#
#       High diploma 1990  Some college 1990  Bachelors or higher 1990  \
# 0                6671.0             4912.0                    3026.0
# 1               20544.0            15900.0                   10870.0
# 2                4258.0             2622.0                    1857.0
# 3                3407.0             1332.0                     476.0
# 4                8763.0             4745.0                    1773.0
# 5                1669.0              954.0                     676.0
# 6                3927.0             2106.0                    1083.0
# 7               21711.0            16835.0                   10266.0
# 8                6749.0             3998.0                    2101.0
# 9                4092.0             1966.0                     866.0
# 10               6770.0             3438.0                    1550.0
# 11               3070.0             1418.0                     836.0
# 12               5445.0             2614.0                    1755.0
# 13               2692.0             1340.0                     628.0
# 14               2394.0             1110.0                     529.0
# 15               6824.0             6354.0                    4274.0
# 16              11110.0             7293.0                    3956.0
# 17               2927.0             1219.0                     574.0
# 18               2403.0             1010.0                     456.0
# 19               6962.0             4642.0                    2198.0
# 20               2444.0             1327.0                     740.0
# 21              13529.0             8882.0                    3405.0
# 22               8199.0             9575.0                    3948.0
# 23               8010.0             5448.0                    3474.0
# 24              10770.0             5529.0                    2520.0
# 25              10188.0             6695.0                    4031.0
# 26               7841.0             3942.0                    1707.0
# 27              20194.0            15201.0                    6689.0
# 28               3700.0             1917.0                     995.0
# 29               5640.0             3171.0                    1269.0
# ...                 ...                ...                       ...
# 3081             3767.0             2006.0                    1186.0
# 3082            23813.0            15174.0                    9478.0
# 3083            63044.0            56285.0                   52986.0
# 3084            13149.0             5265.0                    3306.0
# 3085             5539.0             2457.0                    1326.0
# 3086            35255.0            20302.0                   16162.0
# 3087            19986.0            10338.0                    6315.0
# 3088             3413.0             4863.0                    6279.0
# 3089             2424.0             1726.0                    1003.0
# 3090             6336.0             5512.0                    2630.0
# 3091             4033.0             3041.0                    1484.0
# 3092             2673.0             2091.0                     860.0
# 3093             1191.0              934.0                     518.0
# 3094             6973.0             5614.0                    3412.0
# 3095             2619.0             2267.0                    1145.0
# 3096             1182.0              858.0                     472.0
# 3097             1435.0             1119.0                     740.0
# 3098            13283.0            15763.0                    9467.0
# 3099             2742.0             2058.0                    1075.0
# 3100            11922.0            13020.0                    7823.0
# 3101              598.0              506.0                     229.0
# 3102             4587.0             4798.0                    2763.0
# 3103             2110.0             1526.0                     604.0
# 3104             5260.0             4743.0                    2757.0
# 3105             1063.0              939.0                     681.0
# 3106             8455.0             6912.0                    3006.0
# 3107             2177.0             2549.0                    2291.0
# 3108             3897.0             3028.0                    1425.0
# 3109             1876.0             1406.0                    1000.0
# 3110             1832.0             1107.0                     531.0
#
#       Per less high 1990  Per high diploma 1990  Per some college 1990  \
# 0                   30.0                   32.0                   23.5
# 1                   26.8                   31.8                   24.6
# 2                   44.4                   27.1                   16.7
# 3                   48.2                   33.8                   13.2
# 4                   39.5                   34.7                   18.8
# 5                   51.0                   24.8                   14.2
# 6                   47.2                   29.1                   15.6
# 7                   32.6                   30.0                   23.2
# 8                   45.7                   28.5                   16.9
# 9                   46.5                   31.6                   15.2
# 10                  43.4                   32.6                   16.5
# 11                  45.7                   31.3                   14.5
# 12                  39.7                   33.4                   16.1
# 13                  46.2                   31.1                   15.5
# 14                  50.2                   29.6                   13.7
# 15                  32.8                   26.3                   24.5
# 16                  34.8                   32.4                   21.3
# 17                  47.3                   32.7                   13.6
# 18                  46.1                   33.4                   14.1
# 19                  42.7                   28.9                   19.3
# 20                  48.7                   27.8                   15.1
# 21                  41.2                   30.8                   20.2
# 22                  25.8                   28.0                   32.7
# 23                  40.4                   28.2                   19.2
# 24                  47.0                   30.4                   15.6
# 25                  33.5                   32.4                   21.3
# 26                  40.1                   34.8                   17.5
# 27                  35.9                   30.7                   23.1
# 28                  43.4                   31.7                   16.4
# 29                  44.9                   30.8                   17.3
# ...                  ...                    ...                    ...
# 3081                25.1                   40.5                   21.6
# 3082                18.7                   40.0                   25.5
# 3083                12.0                   32.2                   28.7
# 3084                27.9                   43.7                   17.5
# 3085                30.0                   41.6                   18.5
# 3086                19.4                   39.6                   22.8
# 3087                21.7                   42.7                   22.1
# 3088                10.7                   20.9                   29.8
# 3089                22.9                   36.2                   25.8
# 3090                13.5                   37.8                   32.9
# 3091                18.3                   38.5                   29.0
# 3092                16.6                   39.6                   31.0
# 3093                20.3                   35.9                   28.2
# 3094                22.5                   33.8                   27.2
# 3095                23.5                   33.2                   28.8
# 3096                23.9                   35.8                   26.0
# 3097                20.2                   34.8                   27.1
# 3098                15.8                   29.0                   34.5
# 3099                16.8                   38.8                   29.2
# 3100                14.7                   31.0                   33.9
# 3101                24.3                   34.0                   28.7
# 3102                17.4                   31.2                   32.6
# 3103                20.3                   39.7                   28.7
# 3104                18.4                   33.7                   30.3
# 3105                15.8                   33.4                   29.5
# 3106                18.5                   37.5                   30.7
# 3107                 8.1                   28.5                   33.4
# 3108                15.9                   39.2                   30.5
# 3109                21.2                   34.5                   25.9
# 3110                16.8                   43.9                   26.5
#
#       Per bachelors or higher 1990  Less high 2000  High diploma 2000  \
# 0                             14.5          5872.0             9332.0
# 1                             16.8         17258.0            28428.0
# 2                             11.8          6679.0             6124.0
# 3                              4.7          4984.0             4838.0
# 4                              7.0          9960.0            12136.0
# 5                             10.0          2992.0             2667.0
# 6                              8.0          4439.0             4749.0
# 7                             14.2         19318.0            23856.0
# 8                              8.9          8778.0             7863.0
# 9                              6.7          6138.0             5865.0
# 10                             7.5          8757.0             9264.0
# 11                             8.5          3704.0             3670.0
# 12                            10.8          5165.0             6667.0
# 13                             7.3          3322.0             3690.0
# 14                             6.5          3536.0             3417.0
# 15                            16.5          7755.0             7571.0
# 16                            11.5          9972.0            12665.0
# 17                             6.4          2984.0             3518.0
# 18                             6.3          2831.0             3164.0
# 19                             9.1          8115.0             8473.0
# 20                             8.4          3700.0             2689.0
# 21                             7.8         15322.0            16584.0
# 22                            13.5          6976.0             9159.0
# 23                            12.2          8524.0             9646.0
# 24                             7.1         15469.0            14549.0
# 25                            12.8          9679.0            14576.0
# 26                             7.6          8030.0             8860.0
# 27                            10.2         18115.0            22531.0
# 28                             8.5          4265.0             4404.0
# 29                             6.9          7904.0             6363.0
# ...                            ...             ...                ...
# 3081                          12.8          1828.0             4464.0
# 3082                          15.9          8738.0            27308.0
# 3083                          27.1         19410.0            66651.0
# 3084                          11.0          6022.0            15148.0
# 3085                          10.0          3457.0             7034.0
# 3086                          18.2         13867.0            37849.0
# 3087                          13.5          7662.0            20618.0
# 3088                          38.5          1114.0             3727.0
# 3089                          15.0          1235.0             2506.0
# 3090                          15.7          2343.0             7106.0
# 3091                          14.2          1733.0             3678.0
# 3092                          12.7          1063.0             2766.0
# 3093                          15.6           553.0             1479.0
# 3094                          16.5          3499.0             7658.0
# 3095                          14.5          1283.0             2810.0
# 3096                          14.3           556.0             1270.0
# 3097                          17.9           492.0             1539.0
# 3098                          20.7          5766.0            14053.0
# 3099                          15.2          1093.0             3151.0
# 3100                          20.4          5006.0            13057.0
# 3101                          13.0           220.0              673.0
# 3102                          18.8          2124.0             5208.0
# 3103                          11.4           913.0             2323.0
# 3104                          17.6          2085.0             5180.0
# 3105                          21.4           446.0             1429.0
# 3106                          13.3          2911.0             7994.0
# 3107                          30.0           679.0             2428.0
# 3108                          14.3          1744.0             4069.0
# 3109                          18.4           785.0             1844.0
# 3110                          12.7           674.0             1831.0
#
#       Some college 2000  Bachelors or higher 2000  Per less high 2000  \
# 0                7413.0                    4972.0                21.3
# 1               28178.0                   22146.0                18.0
# 2                4025.0                    2068.0                35.3
# 3                2756.0                     962.0                36.8
# 4                8371.0                    3235.0                29.6
# 5                1325.0                     586.0                39.5
# 6                3146.0                    1433.0                32.2
# 7               19576.0                   11265.0                26.1
# 8                5517.0                    2339.0                35.8
# 9                3186.0                    1636.0                36.5
# 10               5307.0                    2574.0                33.8
# 11               2182.0                    1013.0                35.0
# 12               3733.0                    2137.0                29.2
# 13               1992.0                     763.0                34.0
# 14               1701.0                     879.0                37.1
# 15               7985.0                    5574.0                26.8
# 16               9474.0                    5273.0                26.7
# 17               1877.0                     851.0                32.3
# 18               1597.0                     663.0                34.3
# 19               5975.0                    3142.0                31.6
# 20               1840.0                    1039.0                39.9
# 21              13719.0                    6162.0                29.6
# 22              10857.0                    4398.0                22.2
# 23               6568.0                    4004.0                29.7
# 24               9194.0                    3528.0                36.2
# 25              11749.0                    7173.0                22.4
# 26               5927.0                    2693.0                31.5
# 27              19811.0                    9372.0                25.9
# 28               2753.0                    1157.0                33.9
# 29               4572.0                    2021.0                37.9
# ...                 ...                       ...                 ...
# 3081             3241.0                    1715.0                16.3
# 3082            24606.0                   17057.0                11.2
# 3083            72975.0                   82263.0                 8.0
# 3084             8400.0                    5156.0                17.3
# 3085             3908.0                    1911.0                21.2
# 3086            26351.0                   23028.0                13.7
# 3087            13493.0                    8486.0                15.2
# 3088             4676.0                    7499.0                 6.5
# 3089             2432.0                    1170.0                16.8
# 3090             7508.0                    3150.0                11.7
# 3091             3294.0                    1803.0                16.5
# 3092             2837.0                    1152.0                13.6
# 3093             1177.0                     679.0                14.2
# 3094             7359.0                    4537.0                15.2
# 3095             2747.0                    1566.0                15.3
# 3096             1059.0                     630.0                15.8
# 3097             1843.0                    1107.0                 9.9
# 3098            20784.0                   12438.0                10.9
# 3099             3250.0                    1555.0                12.1
# 3100            16055.0                    8538.0                11.7
# 3101              573.0                     265.0                12.7
# 3102             5756.0                    4057.0                12.4
# 3103             1880.0                     918.0                15.1
# 3104             6689.0                    4026.0                11.6
# 3105             1297.0                     872.0                11.0
# 3106             8220.0                    3928.0                12.6
# 3107             3853.0                    5878.0                 5.3
# 3108             3918.0                    1712.0                15.2
# 3109             1809.0                    1022.0                14.4
# 3110             1389.0                     660.0                14.8
#
#       Per high diploma 2000  Per some college 2000  \
# 0                      33.8                   26.9
# 1                      29.6                   29.3
# 2                      32.4                   21.3
# 3                      35.7                   20.4
# 4                      36.0                   24.8
# 5                      35.2                   17.5
# 6                      34.5                   22.9
# 7                      32.2                   26.4
# 8                      32.1                   22.5
# 9                      34.9                   18.9
# 10                     35.8                   20.5
# 11                     34.7                   20.6
# 12                     37.7                   21.1
# 13                     37.8                   20.4
# 14                     35.8                   17.8
# 15                     26.2                   27.6
# 16                     33.9                   25.3
# 17                     38.1                   20.3
# 18                     38.3                   19.3
# 19                     33.0                   23.2
# 20                     29.0                   19.9
# 21                     32.0                   26.5
# 22                     29.2                   34.6
# 23                     33.6                   22.9
# 24                     34.0                   21.5
# 25                     33.8                   27.2
# 26                     34.7                   23.2
# 27                     32.3                   28.4
# 28                     35.0                   21.9
# 29                     30.5                   21.9
# ...                     ...                    ...
# 3081                   39.7                   28.8
# 3082                   35.1                   31.7
# 3083                   27.6                   30.2
# 3084                   43.6                   24.2
# 3085                   43.1                   24.0
# 3086                   37.4                   26.1
# 3087                   41.0                   26.8
# 3088                   21.9                   27.5
# 3089                   34.1                   33.1
# 3090                   35.3                   37.3
# 3091                   35.0                   31.3
# 3092                   35.4                   36.3
# 3093                   38.0                   30.3
# 3094                   33.2                   31.9
# 3095                   33.4                   32.7
# 3096                   36.1                   30.1
# 3097                   30.9                   37.0
# 3098                   26.5                   39.2
# 3099                   34.8                   35.9
# 3100                   30.6                   37.6
# 3101                   38.9                   33.1
# 3102                   30.4                   33.6
# 3103                   38.5                   31.2
# 3104                   28.8                   37.2
# 3105                   35.3                   32.1
# 3106                   34.7                   35.7
# 3107                   18.9                   30.0
# 3108                   35.6                   34.2
# 3109                   33.8                   33.1
# 3110                   40.2                   30.5
#
#       Per bachelors or higher 2000
# 0                             18.0
# 1                             23.1
# 2                             10.9
# 3                              7.1
# 4                              9.6
# 5                              7.7
# 6                             10.4
# 7                             15.2
# 8                              9.5
# 9                              9.7
# 10                             9.9
# 11                             9.6
# 12                            12.1
# 13                             7.8
# 14                             9.2
# 15                            19.3
# 16                            14.1
# 17                             9.2
# 18                             8.0
# 19                            12.2
# 20                            11.2
# 21                            11.9
# 22                            14.0
# 23                            13.9
# 24                             8.3
# 25                            16.6
# 26                            10.6
# 27                            13.4
# 28                             9.2
# 29                             9.7
# ...                            ...
# 3081                          15.2
# 3082                          21.9
# 3083                          34.1
# 3084                          14.8
# 3085                          11.7
# 3086                          22.8
# 3087                          16.9
# 3088                          44.1
# 3089                          15.9
# 3090                          15.7
# 3091                          17.2
# 3092                          14.7
# 3093                          17.5
# 3094                          19.7
# 3095                          18.6
# 3096                          17.9
# 3097                          22.2
# 3098                          23.4
# 3099                          17.2
# 3100                          20.0
# 3101                          15.3
# 3102                          23.7
# 3103                          15.2
# 3104                          22.4
# 3105                          21.6
# 3106                          17.0
# 3107                          45.8
# 3108                          15.0
# 3109                          18.7
# 3110                          14.5
#
# [3111 rows x 19 columns]

# %%
edu_2000['less high change'] = edu_2000['Less high 2000'] - edu_2000['Less high 1990'] 
edu_2000['high dimploma change'] = edu_2000['High diploma 2000'] - edu_2000['High diploma 1990'] 
edu_2000['some college change'] = edu_2000['Some college 2000'] - edu_2000['Some college 1990']
edu_2000['bachelors change'] = edu_2000['Bachelors or higher 2000'] - edu_2000['Bachelors or higher 1990']

edu_2000['per less high change'] = edu_2000['Per less high 2000'] - edu_2000['Per less high 1990']

edu_2000['per high dimploma change'] = edu_2000['Per high diploma 2000'] - edu_2000['Per high diploma 1990']

edu_2000['per some college change'] = edu_2000['Per some college 2000'] - edu_2000['Per some college 1990']
edu_2000['per bachelors change'] = edu_2000['Per bachelors or higher 2000'] - edu_2000['Per bachelors or higher 1990']
# Out:
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
edu_2010.head()
# Out:
#         county  2013 Continuum  2013 Urban Influence Code  Less high 2000  \
# 0  Autauga, AL               2                          2          5872.0
# 1  Baldwin, AL               3                          2         17258.0
# 2  Barbour, AL               6                          6          6679.0
# 3     Bibb, AL               1                          1          4984.0
# 4   Blount, AL               1                          1          9960.0
#
#    High diploma 2000  Some college 2000  Bachelors or higher 2000  \
# 0             9332.0             7413.0                    4972.0
# 1            28428.0            28178.0                   22146.0
# 2             6124.0             4025.0                    2068.0
# 3             4838.0             2756.0                     962.0
# 4            12136.0             8371.0                    3235.0
#
#    Per less high 2000  Per high diploma 2000  Per some college 2000  \
# 0                21.3                   33.8                   26.9
# 1                18.0                   29.6                   29.3
# 2                35.3                   32.4                   21.3
# 3                36.8                   35.7                   20.4
# 4                29.6                   36.0                   24.8
#
#    Per bachelors or higher 2000  Less high 2011  High diploma 2011  \
# 0                          18.0            4656              12182
# 1                          23.1           14360              39431
# 2                          10.9            5021               6490
# 3                           7.1            3024               6574
# 4                           9.6            8472              13179
#
#    Some college 2011  Bachelors or higher 2011  Per less high 2011  \
# 0              11044                      8437                12.8
# 1              43500                     39710                10.5
# 2               4943                      2354                26.7
# 3               4367                      1664                19.3
# 4              12677                      5080                21.5
#
#    Per high diploma 2011  Per some college 2011  Per bachelors or higher 2011
# 0                   33.5                   30.4                          23.2
# 1                   28.8                   31.8                          29.0
# 2                   34.5                   26.3                          12.5
# 3                   42.1                   27.9                          10.6
# 4                   33.4                   32.2                          12.9

# %%
edu_2010['less high change'] = edu_2010['Less high 2011'] - edu_2010['Less high 2000'] 
edu_2010['high dimploma change'] = edu_2010['High diploma 2011'] - edu_2010['High diploma 2000'] 
edu_2010['some college change'] = edu_2010['Some college 2011'] - edu_2010['Some college 2000']
edu_2010['bachelors change'] = edu_2010['Bachelors or higher 2011'] - edu_2010['Bachelors or higher 2000']
# Out:
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
edu_2010['per less high change'] = edu_2010['Per less high 2011'] - edu_2010['Per less high 2000']
edu_2010['per high diploma change'] = edu_2010['Per high diploma 2011'] - edu_2010['Per high diploma 2000']
edu_2010['per some college change'] = edu_2010['Per some college 2011'] - edu_2010['Per some college 2000']
edu_2010['per bachelors change'] = edu_2010['Per bachelors or higher 2011'] - edu_2010['Per bachelors or higher 2000']
# Out:
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
edu_2000.head()
# Out:
#         county  2003 Continuum  2003 Influence  Less high 1990  \
# 0  Autauga, AL               2               2          6252.0
# 1  Baldwin, AL               4               5         17309.0
# 2  Barbour, AL               6               6          6965.0
# 3     Bibb, AL               1               1          4850.0
# 4   Blount, AL               1               1          9960.0
#
#    High diploma 1990  Some college 1990  Bachelors or higher 1990  \
# 0             6671.0             4912.0                    3026.0
# 1            20544.0            15900.0                   10870.0
# 2             4258.0             2622.0                    1857.0
# 3             3407.0             1332.0                     476.0
# 4             8763.0             4745.0                    1773.0
#
#    Per less high 1990  Per high diploma 1990  Per some college 1990  \
# 0                30.0                   32.0                   23.5
# 1                26.8                   31.8                   24.6
# 2                44.4                   27.1                   16.7
# 3                48.2                   33.8                   13.2
# 4                39.5                   34.7                   18.8
#
#    Per bachelors or higher 1990  Less high 2000  High diploma 2000  \
# 0                          14.5          5872.0             9332.0
# 1                          16.8         17258.0            28428.0
# 2                          11.8          6679.0             6124.0
# 3                           4.7          4984.0             4838.0
# 4                           7.0          9960.0            12136.0
#
#    Some college 2000  Bachelors or higher 2000  Per less high 2000  \
# 0             7413.0                    4972.0                21.3
# 1            28178.0                   22146.0                18.0
# 2             4025.0                    2068.0                35.3
# 3             2756.0                     962.0                36.8
# 4             8371.0                    3235.0                29.6
#
#    Per high diploma 2000  Per some college 2000  Per bachelors or higher 2000  \
# 0                   33.8                   26.9                          18.0
# 1                   29.6                   29.3                          23.1
# 2                   32.4                   21.3                          10.9
# 3                   35.7                   20.4                           7.1
# 4                   36.0                   24.8                           9.6
#
#    less high change  high dimploma change  some college change  \
# 0            -380.0                2661.0               2501.0
# 1             -51.0                7884.0              12278.0
# 2            -286.0                1866.0               1403.0
# 3             134.0                1431.0               1424.0
# 4               0.0                3373.0               3626.0
#
#    bachelors change  per less high change  per high dimploma change  \
# 0            1946.0                  -8.7                       1.8
# 1           11276.0                  -8.8                      -2.2
# 2             211.0                  -9.1                       5.3
# 3             486.0                 -11.4                       1.9
# 4            1462.0                  -9.9                       1.3
#
#    per some college change  per bachelors change
# 0                      3.4                   3.5
# 1                      4.7                   6.3
# 2                      4.6                  -0.9
# 3                      7.2                   2.4
# 4                      6.0                   2.6

# %%
edu_2010.head()
# Out:
#         county  2013 Continuum  2013 Urban Influence Code  Less high 2000  \
# 0  Autauga, AL               2                          2          5872.0
# 1  Baldwin, AL               3                          2         17258.0
# 2  Barbour, AL               6                          6          6679.0
# 3     Bibb, AL               1                          1          4984.0
# 4   Blount, AL               1                          1          9960.0
#
#    High diploma 2000  Some college 2000  Bachelors or higher 2000  \
# 0             9332.0             7413.0                    4972.0
# 1            28428.0            28178.0                   22146.0
# 2             6124.0             4025.0                    2068.0
# 3             4838.0             2756.0                     962.0
# 4            12136.0             8371.0                    3235.0
#
#    Per less high 2000  Per high diploma 2000  Per some college 2000  \
# 0                21.3                   33.8                   26.9
# 1                18.0                   29.6                   29.3
# 2                35.3                   32.4                   21.3
# 3                36.8                   35.7                   20.4
# 4                29.6                   36.0                   24.8
#
#    Per bachelors or higher 2000  Less high 2011  High diploma 2011  \
# 0                          18.0            4656              12182
# 1                          23.1           14360              39431
# 2                          10.9            5021               6490
# 3                           7.1            3024               6574
# 4                           9.6            8472              13179
#
#    Some college 2011  Bachelors or higher 2011  Per less high 2011  \
# 0              11044                      8437                12.8
# 1              43500                     39710                10.5
# 2               4943                      2354                26.7
# 3               4367                      1664                19.3
# 4              12677                      5080                21.5
#
#    Per high diploma 2011  Per some college 2011  Per bachelors or higher 2011  \
# 0                   33.5                   30.4                          23.2
# 1                   28.8                   31.8                          29.0
# 2                   34.5                   26.3                          12.5
# 3                   42.1                   27.9                          10.6
# 4                   33.4                   32.2                          12.9
#
#    less high change  high dimploma change  some college change  \
# 0           -1216.0                2850.0               3631.0
# 1           -2898.0               11003.0              15322.0
# 2           -1658.0                 366.0                918.0
# 3           -1960.0                1736.0               1611.0
# 4           -1488.0                1043.0               4306.0
#
#    bachelors change  per less high change  per high diploma change  \
# 0            3465.0                  -8.5                     -0.3
# 1           17564.0                  -7.5                     -0.8
# 2             286.0                  -8.6                      2.1
# 3             702.0                 -17.5                      6.4
# 4            1845.0                  -8.1                     -2.6
#
#    per some college change  per bachelors change
# 0                      3.5                   5.2
# 1                      2.5                   5.9
# 2                      5.0                   1.6
# 3                      7.5                   3.5
# 4                      7.4                   3.3

# %%
# Townhall distingushes cities that share a name with counties with a 'Co.', 
# and all other cites have only the city name.

# Finds the cities and counties with the same name, creates a list of these duplicates.
uni = []
for count in edu_2000.county:
    if count[-5] == '.':
        x = count[:-8]+count[-4:]
        uni.append(x)
    else:
        uni.append(count)

# cities in this list keep Co. all others drop it

repeted_counties = list({x for x in uni if uni.count(x) > 1})

# removes the 'Co.' from all cities that don't have a count of the same name.

new_county = []
for count in edu_2000.county:
    if 'Co.' in count:
        if count[:-8] + count[-4:] not in repeted_counties:
            new_county.append(count[:-8] + count[-4:])
        elif count[:-8] + count[-4:] in repeted_counties:
            new_county.append(count)
    else:
        new_county.append(count)
new_county_2 = []            
for count in new_county:
    if 'Saint ' in count:
        count = count.replace('Saint', 'St.')
        new_county_2.append(count)
    elif 'Dekalb' in count:
        count = count.replace('Dekalb', 'DeKalb')
        new_county_2.append(count)
    elif 'Desoto' in count:
        count = count.replace('Desoto', 'DeSoto')
        new_county_2.append(count)
    elif 'Lamoure' in count:
        count = count.replace('Lamoure', 'LaMoure')
        new_county_2.append(count)
    elif 'Mc Kean' in count:
        count = count.replace('Mc Kean', 'McKean')
        new_county_2.append(count) 
    elif 'Du Page' in count:
        count = count.replace('Du Page', 'DuPage')
        new_county_2.append(count)
    elif 'Dewitt' in count:
        count = count.replace('Dewitt', 'DeWitt') 
        new_county_2.append(count)
    elif 'Debaca' in count:
        count = count.replace('Debaca', 'De Baca')
        new_county_2.append(count)
    elif 'Baltimore Co.' in count:
        count = count.replace('Baltimore Co.', 'Baltimore City')
        new_county_2.append(count)
    elif count == 'Baltimore, MD':
        count = count.replace('Baltimore, MD', 'Baltimore County, MD')
        new_county_2.append(count) 
    elif count == 'Carson, NV':
        count = count.replace('Carson, NV', 'Carson City, NV')
        new_county_2.append(count)    
    elif count == 'Shannon, SD':
        count = count.replace('Shannon, SD', 'Oglala Lakota, SD')
        new_county_2.append(count)     
    else:
        new_county_2.append(count)

# %%
edu_2000.county = new_county_2
edu_2010.county = new_county_2
# Out:
# /Users/Penelope/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
edu_2000.to_csv('./csv_files/edu_2000', index=False)
edu_2010.to_csv('./csv_files/edu_2010', index=False)
